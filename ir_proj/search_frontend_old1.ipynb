# %% [markdown]
# # YAY Project!!

# %%
# !pip install -q pyspark
# !pip install graphframes  # wasnt used like this in their code?
# !pip install -U -q PyDrive
# !apt-get update -qq
# !apt install openjdk-8-jdk-headless -qq
# Out:
#      |████████████████████████████████| 281.3 MB 38 kB/s
#      |████████████████████████████████| 198 kB 49.0 MB/s
#   Building wheel for pyspark (setup.py) ... done
# Collecting graphframes
#   Downloading graphframes-0.6-py2.py3-none-any.whl (18 kB)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 33.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from graphframes) (1.19.5)
# Installing collected packages: nose, graphframes
# Successfully installed graphframes-0.6 nose-1.3.7
# The following additional packages will be installed:
#   openjdk-8-jre-headless
# Suggested packages:
#   openjdk-8-demo openjdk-8-source libnss-mdns fonts-dejavu-extra
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   openjdk-8-jdk-headless openjdk-8-jre-headless
# 0 upgraded, 2 newly installed, 0 to remove and 100 not upgraded.
# Need to get 36.5 MB of archives.
# After this operation, 143 MB of additional disk space will be used.
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../openjdk-8-jre-headless_8u312-b07-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../openjdk-8-jdk-headless_8u312-b07-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# Setting up openjdk-8-jre-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up openjdk-8-jdk-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/idlj to provide /usr/bin/idlj (idlj) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsimport to provide /usr/bin/wsimport (wsimport) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jsadebugd to provide /usr/bin/jsadebugd (jsadebugd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/native2ascii to provide /usr/bin/native2ascii (native2ascii) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javah to provide /usr/bin/javah (javah) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/hsdb to provide /usr/bin/hsdb (hsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/clhsdb to provide /usr/bin/clhsdb (clhsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/xjc to provide /usr/bin/xjc (xjc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/schemagen to provide /usr/bin/schemagen (schemagen) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/extcheck to provide /usr/bin/extcheck (extcheck) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jhat to provide /usr/bin/jhat (jhat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsgen to provide /usr/bin/wsgen (wsgen) in auto mode

# %%
spark_jars = '/usr/local/lib/python3.7/dist-packages/pyspark/jars'
graphframes_jar = 'https://repos.spark-packages.org/graphframes/graphframes/0.8.2-spark3.2-s_2.12/graphframes-0.8.2-spark3.2-s_2.12.jar'
# !wget -N -P $spark_jars $graphframes_jar
# Out:
# --2022-01-03 16:06:15--  https://repos.spark-packages.org/graphframes/graphframes/0.8.2-spark3.2-s_2.12/graphframes-0.8.2-spark3.2-s_2.12.jar
# Resolving repos.spark-packages.org (repos.spark-packages.org)... 52.85.146.93, 52.85.146.12, 52.85.146.3, ...
# Connecting to repos.spark-packages.org (repos.spark-packages.org)|52.85.146.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247880 (242K) [binary/octet-stream]
# Saving to: ‘/usr/local/lib/python3.7/dist-packages/pyspark/jars/graphframes-0.8.2-spark3.2-s_2.12.jar’
#
# graphframes-0.8.2-s 100%[===================>] 242.07K  --.-KB/s    in 0.006s
#
# 2022-01-03 16:06:16 (42.5 MB/s) - ‘/usr/local/lib/python3.7/dist-packages/pyspark/jars/graphframes-0.8.2-spark3.2-s_2.12.jar’ saved [247880/247880]

# %%
# pyspark imports
import pyspark
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.ml.feature import Tokenizer, RegexTokenizer
from graphframes import *

# %%
from flask import Flask, request, jsonify
import sys
import re
from collections import Counter, OrderedDict, defaultdict
import itertools
from itertools import islice, count, groupby
import os
import operator
from operator import itemgetter
from pathlib import Path
import pickle
from contextlib import closing
import numpy as np
import pandas as pd
import math
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import hashlib
def _hash(s):
    return hashlib.blake2b(bytes(s, encoding='utf8'), digest_size=5).hexdigest()

# %%
# Initializing spark context
# create a spark context and session
conf = SparkConf().set("spark.ui.port", "4050")
sc = pyspark.SparkContext(conf=conf)
sc.addPyFile(str(Path(spark_jars) / Path(graphframes_jar).name))
spark = SparkSession.builder.getOrCreate()

# %%
# Copy one wikidumps files 
import os
from pathlib import Path
from google.colab import auth

project_id = 'core-period-321814'
# !gcloud config set project {project_id}

data_bucket_name = 'wikidata_preprocessed'
try:
    if os.environ["wikidata_preprocessed"] is not None:
        pass  
except:
      # !mkdir wikidumps
      # !gsutil cp gs://{data_bucket_name}/multistream1_preprocessed.parquet "wikidumps/"
# Out:
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey
#
# Copying gs://wikidata_preprocessed/multistream1_preprocessed.parquet...
# / [1 files][316.7 MiB/316.7 MiB]
# Operation completed over 1 objects/316.7 MiB.

# %%
from pathlib import Path 
import os

try:
    if os.environ["wikidata_preprocessed"] is not None:
      path = os.environ["wikidata_preprocessed"]+"/wikidumps/*"
except:
      path = "wikidumps/*"

parquetFile = spark.read.parquet(path)
parquetFile.show()
# Out:
# +---+--------------------+--------------------+--------------------+
# | id|               title|                text|         anchor_text|
# +---+--------------------+--------------------+--------------------+
# | 12|           Anarchism|'''Anarchism''' i...|[{23040, politica...|
# | 25|              Autism|'''Autism''' is a...|[{492271, Clinica...|
# | 39|              Albedo|thumb|upright=1.3...|[{679294, diffuse...|
# |290|                   A|'''A''', or '''a'...|[{290, See below}...|
# |303|             Alabama|'''Alabama''' () ...|[{351590, Yellowh...|
# |305|            Achilles|thumb|260px|Ancie...|[{1076007, potter...|
# |307|     Abraham Lincoln|'''Abraham Lincol...|[{1827174, Alexan...|
# |308|           Aristotle|'''Aristotle''' (...|[{1389981, bust},...|
# |309|An American in Paris|'''''An American ...|[{13066, George G...|
# |316|Academy Award for...|The '''Academy Aw...|[{39842, Academy ...|
# |324|      Academy Awards|The '''Academy Aw...|[{649481, film in...|
# |330|             Actrius|'''''Actresses'''...|[{5282, Catalan},...|
# |332|     Animalia (book)|'''''Animalia''''...|[{2511084, Graeme...|
# |334|International Ato...|'''International ...|[{25453985, atomi...|
# |336|            Altruism|thumb|Giving alms...|[{657573, alms}, ...|
# |339|            Ayn Rand|'''Alice O'Connor...|[{24320051, St. P...|
# |340|        Alain Connes|'''Alain Connes''...|[{1201522, Dragui...|
# |344|          Allan Dwan|'''Allan Dwan''' ...|[{64646, Toronto}...|
# |358|             Algeria|'''Algeria''', of...|[{803, Arabic}, {...|
# |359|List of Atlas Shr...|This is a list of...|[{339, Ayn Rand},...|
# +---+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# take the 'text' and 'id' or the first 1000 rows and create an RDD from it
doc_text_pairs = parquetFile.limit(1000).select("text", "id").rdd

# %%
english_stopwords = frozenset(stopwords.words('english'))
corpus_stopwords = ['category', 'references', 'also', 'links', 'extenal', 'see', 'thumb']
RE_WORD = re.compile(r"""[\#\@\w](['\-]?\w){2,24}""", re.UNICODE)

all_stopwords = english_stopwords.union(corpus_stopwords)

def word_count(text, id):
  ''' Count the frequency of each word in `text` (tf) that is not included in 
  `all_stopwords` and return entries that will go into our posting lists. 
  Parameters:
  -----------
    text: str
      Text of one document
    id: int
      Document id
  Returns:
  --------
    List of tuples
      A list of (token, (doc_id, tf)) pairs 
      for example: [("Anarchism", (12, 5)), ...]
  '''
  tokens = [token.group() for token in RE_WORD.finditer(text.lower())]
  # YOUR CODE HERE
  word_dict = dict()
  for word in tokens:
    if word in all_stopwords:
      continue
    if word not in word_dict.keys():
      word_dict[word] = [id, 0]
    word_dict[word][1] += 1
  res = [(entry[0], tuple(entry[1])) for entry in word_dict.items()]
  return res

# %%
word_counts = doc_text_pairs.flatMap(lambda x: word_count(x[0], x[1]))

# %%
def reduce_word_counts(unsorted_pl):
  ''' Returns a sorted posting list by wiki_id.
  Parameters:
  -----------
    unsorted_pl: list of tuples
      A list of (wiki_id, tf) tuples 
  Returns:
  --------
    list of tuples
      A sorted posting list.
  '''
  l = list(unsorted_pl)
  return sorted(l, key = lambda item: item[0])

# %%
postings = word_counts.groupByKey().mapValues(reduce_word_counts)

# %%
postings_filtered = postings.filter(lambda x: len(x[1])>50)

# %%
def calculate_df(postings):
  ''' Takes a posting list RDD and calculate the df for each token.
  Parameters:
  -----------
    postings: RDD
      An RDD where each element is a (token, posting_list) pair.
  Returns:
  --------
    RDD
      An RDD where each element is a (token, df) pair.
  '''
  return postings.mapValues(len) 

w2df = calculate_df(postings_filtered)

# %%
NUM_BUCKETS = 124
def token2bucket_id(token):
  return int(_hash(token),16) % NUM_BUCKETS

def partition_postings_and_write(postings):
  ''' A function that partitions the posting lists into buckets, writes out 
  all posting lists in a bucket to disk, and returns the posting locations for 
  each bucket. Partitioning should be done through the use of `token2bucket` 
  above. Writing to disk should use the function  `write_a_posting_list`, a 
  static method implemented in inverted_index_colab.py under the InvertedIndex 
  class. 
  Parameters:
  -----------
    postings: RDD
      An RDD where each item is a (w, posting_list) pair.
  Returns:
  --------
    RDD
      An RDD where each item is a posting locations dictionary for a bucket. The
      posting locations maintain a list for each word of file locations and 
      offsets its posting list was written to. See `write_a_posting_list` for 
      more details.
  '''
  r1 = postings.map(lambda tup: (token2bucket_id(tup[0]), [tup]))
  r2 = r1.reduceByKey(lambda p_lst1, p_lst2: p_lst1 + p_lst2) # group_by_key
  r3 = r2.map(lambda tup: InvertedIndex.write_a_posting_list(tup))
  return r3

# %%
posting_locs_list = partition_postings_and_write(postings_filtered).collect()
super_posting_locs = defaultdict(list)
for posting_loc in posting_locs_list:
  for k, v in posting_loc.items():
    super_posting_locs[k].extend(v)

w2df_dict = w2df.collectAsMap()

# %%
# Create inverted index instance
inverted = InvertedIndex()
# Adding the posting locations dictionary to the inverted index
inverted.posting_locs = super_posting_locs
# Add the token - df dictionary to the inverted index
inverted.df = w2df_dict
# write the global stats out
inverted.write_index('.', 'index')

# %% [markdown]
# ### Functions from previous Assignments

# %%
def get_posting_gen(index):
    """
    This function returning the generator working with posting list.

    Parameters:
    ----------
    index: inverted index
    """
    words, pls = zip(*index.posting_lists_iter())
    return words, pls

def cosine_similarity(D, Q):
    """
    Calculate the cosine similarity for each candidate document in D and a given query (e.g., Q).
    Generate a dictionary of cosine similarity scores
    key: doc_id
    value: cosine similarity score

    Parameters:
    -----------
    D: DataFrame of tfidf scores.

    Q: vectorized query with tfidf scores

    Returns:
    -----------
    dictionary of cosine similarity score as follows:
                                                                key: document id (e.g., doc_id)
                                                                value: cosine similarty score.
    """
    doc_sizes = np.linalg.norm(D, axis=1)
    query_size = np.linalg.norm(Q)
    cos_normalizers = doc_sizes * query_size
    dot_prod = np.dot(D, Q)  # supposed to give a 1d
    cos_sims = dot_prod / cos_normalizers
    sim_dict = dict()
    for ind, doc_id in enumerate(D.T.columns):
        sim_dict[doc_id] = cos_sims[ind]
    return sim_dict

def generate_document_tfidf_matrix(query_to_search, index, words, pls):
    """
    Generate a DataFrame `D` of tfidf scores for a given query.
    Rows will be the documents candidates for a given query
    Columns will be the unique terms in the index.
    The value for a given document and term will be its tfidf score.

    Parameters:
    -----------
    query_to_search: list of tokens (str). This list will be preprocessed in advance (e.g., lower case, filtering stopwords, etc.').
                     Example: 'Hello, I love information retrival' --->  ['hello','love','information','retrieval']

    index:           inverted index loaded from the corresponding files.

    words,pls: generator for working with posting.
    Returns:
    -----------
    DataFrame of tfidf scores.
    """
    print(f"Query: {query_to_search} \nwords:{words}")
    total_vocab_size = len(index.term_total)
    candidates_scores = get_candidate_documents_and_scores(query_to_search, index, words,
                                                           pls)  # We do not need to utilize all document. Only the docuemnts which have corrspoinding terms with the query.
    print(candidates_scores)
    unique_candidates = np.unique([doc_id for doc_id, freq in candidates_scores.keys()])
    D = np.zeros((len(unique_candidates), total_vocab_size))
    D = pd.DataFrame(D)
    

    D.index = unique_candidates
    D.columns = index.term_total.keys()
    print(f"D2: \n{D}" )
    for key in candidates_scores:
        tfidf = candidates_scores[key]
        doc_id, term = key
        D.loc[doc_id][term] = tfidf

    return D

def generate_query_tfidf_vector(query_to_search, index):
    """
    Generate a vector representing the query. Each entry within this vector represents a tfidf score.
    The terms representing the query will be the unique terms in the index.

    We will use tfidf on the query as well.
    For calculation of IDF, use log with base 10.
    tf will be normalized based on the length of the query.

    Parameters:
    -----------
    query_to_search: list of tokens (str). This list will be preprocessed in advance (e.g., lower case, filtering stopwords, etc.').
                     Example: 'Hello, I love information retrival' --->  ['hello','love','information','retrieval']

    index:           inverted index loaded from the corresponding files.

    Returns:
    -----------
    vectorized query with tfidf scores
    """

    epsilon = .0000001
    total_vocab_size = len(index.term_total)
    Q = np.zeros((total_vocab_size))
    term_vector = list(index.term_total.keys())
    counter = Counter(query_to_search)
    for token in np.unique(query_to_search):
        if token in index.term_total.keys():  # avoid terms that do not appear in the index.
            tf = counter[token] / len(query_to_search)  # term frequency divded by the length of the query
            df = index.df[token]
            idf = math.log((len(DL)) / (df + epsilon), 10)  # smoothing

            try:
                ind = term_vector.index(token)
                Q[ind] = tf * idf
            except:
                pass
    return Q

def get_candidate_documents_and_scores(query_to_search, index, words, pls):
    """
    Generate a dictionary representing a pool of candidate documents for a given query. This function will go through every token in query_to_search
    and fetch the corresponding information (e.g., term frequency, document frequency, etc.') needed to calculate TF-IDF from the posting list.
    Then it will populate the dictionary 'candidates.'
    For calculation of IDF, use log with base 10.
    tf will be normalized based on the length of the document.

    Parameters:
    -----------
    query_to_search: list of tokens (str). This list will be preprocessed in advance (e.g., lower case, filtering stopwords, etc.').
                     Example: 'Hello, I love information retrival' --->  ['hello','love','information','retrieval']

    index:           inverted index loaded from the corresponding files.

    words,pls: generator for working with posting.
    Returns:
    -----------
    dictionary of candidates. In the following format:
                                                               key: pair (doc_id,term)
                                                               value: tfidf score.
    """
    candidates = {}
    N = len(DL)
    print("QueryToSearch ", query_to_search)
    for term in np.unique(query_to_search):
        if term in words:
            list_of_doc = pls[words.index(term)]
            #nizan###changed str to int in doc
            normlized_tfidf = [(doc_id, (freq / DL[int(doc_id)]) * math.log(N / index.df[term], 10)) for doc_id, freq in
                               list_of_doc]

            for doc_id, tfidf in normlized_tfidf:
                candidates[(doc_id, term)] = candidates.get((doc_id, term), 0) + tfidf

    return candidates

def get_topN_score_for_queries(queries_to_search, index, N=3):
    """
    Generate a dictionary that gathers for every query its topN score.

    Parameters:
    -----------
    queries_to_search: a dictionary of queries as follows:
                                                        key: query_id
                                                        value: list of tokens.
    index:           inverted index loaded from the corresponding files.
    N: Integer. How many documents to retrieve. This argument is passed to the topN function. By default N = 3, for the topN function.

    Returns:
    -----------
    return: a dictionary of queries and topN pairs as follows:
                                                        key: query_id
                                                        value: list of pairs in the following format:(doc_id, score).
    """
    words, p_lst = get_posting_gen(index)

    # inits dict with empty lists
    top_n_dict = dict(zip(queries_to_search.keys(), [[]] * len(queries_to_search.keys())))

    for query_id, toks in queries_to_search.items():
        doc_tfidf_mat = generate_document_tfidf_matrix(toks, index, words, p_lst)
        query_tfidf = generate_query_tfidf_vector(toks, index)
        cos_sim_dict = cosine_similarity(doc_tfidf_mat, query_tfidf)
        top_n_dict[query_id] = get_top_n(cos_sim_dict, N)
    return top_n_dict

def get_top_n(sim_dict,N=3):
    """ 
    Sort and return the highest N documents according to the cosine similarity score.
    Generate a dictionary of cosine similarity scores 
   
    Parameters:
    -----------
    sim_dict: a dictionary of similarity score as follows:
                                                                key: document id (e.g., doc_id)
                                                                value: similarity score. We keep up to 5 digits after the decimal point. (e.g., round(score,5))

    N: Integer (how many documents to retrieve). By default N = 3
    
    Returns:
    -----------
    a ranked list of pairs (doc_id, score) in the length of N.
    """
    #print(sim_dict.items())
    if len(sim_dict.items()) < N:
      N = len(sim_dict.items())
    #print(N)
    #print(type(sim_dict))
    #return sorted([(doc_id,round(score,5)) for doc_id, score in sim_dict.items()], key = lambda x: x[1],reverse=True)[:N]
    new_dict = dict(sorted(sim_dict.items(), key=lambda item: item[1]))
    return list(new_dict.items())[:N]

# %% [markdown]
# # Search frontend

# %%
# Tests
# NOTE May need token2bucket. Our tokenizer isnt from a3 gcp.
def body_index():
    res = []
    query = "computer engineering" # query = request.args.get('query', '')
    if len(query) == 0:
      return jsonify(res)
    
    # BEGIN SOLUTION
    # text_list = []
    # doc_dict = dict()  # need to pass {doc_id: token_list} into index constructor
    #
    # for index, text in enumerate(text_list):
    #     # we will use the index as doc_id. (Will cause bugs if the program is shut down and booted up again)
    #     # Solution: save the last index to disk, and add it as an offset to the new indicies
    #     doc_dict[index] = tokenize(text)
    #
    # text_index = InvertedIndex(docs=doc_dict)

    doc_test = {}
    doc_test[1] = 'hi this is number 1 data'
    doc_test[2] = 'computer is the best'
    doc_test[3] = 'data engineering is the best'
    doc_test[4] = 'data is importent'

    query = tokenize(query)
    for key in doc_test.keys():
        doc_test[key] = tokenize(doc_test[key])
    index = InvertedIndex(docs=doc_test)
    index.write('.', 'test')
    index2 = InvertedIndex.read_index('.', 'test')  

    words, p_lst = get_posting_gen(index2)
    #nizan### changed from index to index 2
    doc_tfidf_mat = generate_document_tfidf_matrix(query, index2, words, p_lst)
    query_tfidf = generate_query_tfidf_vector(query, index2)
    cos_sim_dict = cosine_similarity(doc_tfidf_mat, query_tfidf)
    top_n = get_top_n(cos_sim_dict, 100)
    print(top_n)
    
    # END SOLUTION
    return jsonify(res)
body_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-86a55f1535d1> in <module>()
#      41     # END SOLUTION
#      42     return jsonify(res)
# ---> 43 body_index()
#
# <ipython-input-35-86a55f1535d1> in body_index()
#      28         doc_test[key] = tokenize(doc_test[key])
#      29     index = InvertedIndex(docs=doc_test)
# ---> 30     index.write('.', 'test')
#      31     index2 = InvertedIndex.read_index('.', 'test')
#      32
#
# AttributeError: 'InvertedIndex' object has no attribute 'write'

# %%
class MyFlaskApp(Flask):
    def run(self, host=None, port=None, debug=None, **options):
        super(MyFlaskApp, self).run(host=host, port=port, debug=debug, **options)

app = MyFlaskApp(__name__)
app.config['JSONIFY_PRETTYPRINT_REGULAR'] = False


@app.route("/search")
def search():
    ''' Returns up to a 100 of your best search results for the query. This is 
        the place to put forward your best search engine, and you are free to
        implement the retrieval whoever you'd like within the bound of the 
        project requirements (efficiency, quality, etc.). That means it is up to
        you to decide on whether to use stemming, remove stopwords, use 
        PageRank, query expansion, etc.

        To issue a query navigate to a URL like:
         http://YOUR_SERVER_DOMAIN/search?query=hello+world
        where YOUR_SERVER_DOMAIN is something like XXXX-XX-XX-XX-XX.ngrok.io
        if you're using ngrok on Colab or your external IP on GCP.
    Returns:
    --------
        list of up to 100 search results, ordered from best to worst where each 
        element is a tuple (wiki_id, title).
    '''
    res = []
    query = request.args.get('query', '')
    if len(query) == 0:
      return jsonify(res)
    # BEGIN SOLUTION

    # END SOLUTION
    return jsonify(res)

@app.route("/search_body")
def search_body():
    ''' Returns up to a 100 search results for the query using TFIDF AND COSINE
        SIMI.LARITY OF THE BODY OF ARTICLES ONLY DO NOT use stemming. DO USE the
        staff-provided tokenizer from Assignment 3 (GCP part) to do the
        tokenization and remove stopwords. 

        To issue a query navigate to a URL like:
         http://YOUR_SERVER_DOMAIN/search_body?query=hello+world
        where YOUR_SERVER_DOMAIN is something like XXXX-XX-XX-XX-XX.ngrok.io
        if you're using ngrok on Colab or your external IP on GCP.
    Returns:
    --------
        list of up to 100 search results, ordered from best to worst where each 
        element is a tuple (wiki_id, title).
    '''

    # NOTE May need token2bucket. Our tokenizer isnt from a3 gcp.
    res = []
    query = "first test"#request.args.get('query', '')
    if len(query) == 0:
      return jsonify(res)
    # BEGIN SOLUTION
    # text_list = []
    # doc_dict = dict()  # need to pass {doc_id: token_list} into index constructor
    #
    # for index, text in enumerate(text_list):
    #     # we will use the index as doc_id. (Will cause bugs if the program is shut down and booted up again)
    #     # Solution: save the last index to disk, and add it as an offset to the new indicies
    #     doc_dict[index] = tokenize(text)
    #
    # text_index = InvertedIndex(docs=doc_dict)
    '''
    doc_test = {}
    doc_test[1] = 'hi this is number 1 data'
    doc_test[2] = 'computer is the best'
    doc_test[3] = 'data engeeniring is the best'
    doc_test[4] = 'data is importent'

    for key in doc_test.keys():
        doc_test[key] = tokenize(doc_test[key])

    text_index = InvertedIndex(docs=doc_test)
    '''
    query = tokenize(query)
    index = inverted
    words, p_lst = get_posting_gen(index)
    #nizan### changed from index to index 2
    doc_tfidf_mat = generate_document_tfidf_matrix(query, index, words, p_lst)
    print(doc_tfidf_mat)
    query_tfidf = generate_query_tfidf_vector(query, index)
    cos_sim_dict = cosine_similarity(doc_tfidf_mat, query_tfidf)
    top_n = get_top_n(cos_sim_dict, 100)
    print(top_n)

    # END SOLUTION
    return jsonify(res)

# Many of these functions use numpy and pandas:

@app.route("/search_title")
def search_title():
    ''' Returns ALL (not just top 100) search results that contain A QUERY WORD 
        IN THE TITLE of articles, ordered in descending order of the NUMBER OF 
        QUERY WORDS that appear in the title. For example, a document with a 
        title that matches two of the query words will be ranked before a 
        document with a title that matches only one query term. 

        Test this by navigating to the a URL like:
         http://YOUR_SERVER_DOMAIN/search_title?query=hello+world
        where YOUR_SERVER_DOMAIN is something like XXXX-XX-XX-XX-XX.ngrok.io
        if you're using ngrok on Colab or your external IP on GCP.
    Returns:
    --------
        list of ALL (not just top 100) search results, ordered from best to 
        worst where each element is a tuple (wiki_id, title).
    '''
    res = []
    query = request.args.get('query', '')
    if len(query) == 0:
      return jsonify(res)
    # BEGIN SOLUTION

    # END SOLUTION
    return jsonify(res)

@app.route("/search_anchor")
def search_anchor():
    ''' Returns ALL (not just top 100) search results that contain A QUERY WORD 
        IN THE ANCHOR TEXT of articles, ordered in descending order of the 
        NUMBER OF QUERY WORDS that appear in anchor text linking to the page. 
        For example, a document with a anchor text that matches two of the 
        query words will be ranked before a document with anchor text that 
        matches only one query term. 

        Test this by navigating to the a URL like:
         http://YOUR_SERVER_DOMAIN/search_anchor?query=hello+world
        where YOUR_SERVER_DOMAIN is something like XXXX-XX-XX-XX-XX.ngrok.io
        if you're using ngrok on Colab or your external IP on GCP.
    Returns:
    --------
        list of ALL (not just top 100) search results, ordered from best to 
        worst where each element is a tuple (wiki_id, title).
    '''
    res = []
    query = request.args.get('query', '')
    if len(query) == 0:
      return jsonify(res)
    # BEGIN SOLUTION
    
    # END SOLUTION
    return jsonify(res)

@app.route("/get_pagerank", methods=['POST'])
def get_pagerank():
    ''' Returns PageRank values for a list of provided wiki article IDs. 

        Test this by issuing a POST request to a URL like:
          http://YOUR_SERVER_DOMAIN/get_pagerank
        with a json payload of the list of article ids. In python do:
          import requests
          requests.post('http://YOUR_SERVER_DOMAIN/get_pagerank', json=[1,5,8])
        As before YOUR_SERVER_DOMAIN is something like XXXX-XX-XX-XX-XX.ngrok.io
        if you're using ngrok on Colab or your external IP on GCP.
    Returns:
    --------
        list of floats:
          list of PageRank scores that correrspond to the provided article IDs.
    '''
    res = []
    wiki_ids = request.get_json()
    if len(wiki_ids) == 0:
      return jsonify(res)
    # BEGIN SOLUTION

    # END SOLUTION
    return jsonify(res)

@app.route("/get_pageview", methods=['POST'])
def get_pageview():
    ''' Returns the number of page views that each of the provide wiki articles
        had in August 2021.

        Test this by issuing a POST request to a URL like:
          http://YOUR_SERVER_DOMAIN/get_pageview
        with a json payload of the list of article ids. In python do:
          import requests
          requests.post('http://YOUR_SERVER_DOMAIN/get_pageview', json=[1,5,8])
        As before YOUR_SERVER_DOMAIN is something like XXXX-XX-XX-XX-XX.ngrok.io
        if you're using ngrok on Colab or your external IP on GCP.
    Returns:
    --------
        list of ints:
          list of page view numbers from August 2021 that correrspond to the 
          provided list article IDs.
    '''
    res = []
    wiki_ids = request.get_json()
    if len(wiki_ids) == 0:
      return jsonify(res)
    # BEGIN SOLUTION

    # END SOLUTION
    return jsonify(res)

search_body()
# Out:
# Streaming output truncated to the last 5000 lines.
# locs:[('117_000.bin', 972)]
# PostingLocsIter: w:easy,
# locs:[('117_000.bin', 1446)]
# PostingLocsIter: w:already,
# locs:[('117_000.bin', 1980)]
# PostingLocsIter: w:established,
# locs:[('117_000.bin', 3438)]
# PostingLocsIter: w:stated,
# locs:[('117_000.bin', 5616)]
# PostingLocsIter: w:notion,
# locs:[('117_000.bin', 7050)]
# PostingLocsIter: w:breaking,
# locs:[('117_000.bin', 7512)]
# PostingLocsIter: w:research,
# locs:[('117_000.bin', 7872)]
# PostingLocsIter: w:words,
# locs:[('117_000.bin', 9546)]
# PostingLocsIter: w:linked,
# locs:[('117_000.bin', 10962)]
# PostingLocsIter: w:narrow,
# locs:[('117_000.bin', 11550)]
# PostingLocsIter: w:1891,
# locs:[('117_000.bin', 11940)]
# PostingLocsIter: w:rapid,
# locs:[('117_000.bin', 12390)]
# PostingLocsIter: w:four,
# locs:[('117_000.bin', 13032)]
# PostingLocsIter: w:1929,
# locs:[('117_000.bin', 15876)]
# PostingLocsIter: w:plans,
# locs:[('117_000.bin', 16632)]
# PostingLocsIter: w:travel,
# locs:[('117_000.bin', 17274)]
# PostingLocsIter: w:fragments,
# locs:[('117_000.bin', 18078)]
# PostingLocsIter: w:guard,
# locs:[('117_000.bin', 18516)]
# PostingLocsIter: w:faced,
# locs:[('117_000.bin', 19002)]
# PostingLocsIter: w:imperial,
# locs:[('117_000.bin', 19554)]
# PostingLocsIter: w:singer,
# locs:[('117_000.bin', 20346)]
# PostingLocsIter: w:bases,
# locs:[('117_000.bin', 21066)]
# PostingLocsIter: w:enhanced,
# locs:[('117_000.bin', 21390)]
# PostingLocsIter: w:1923,
# locs:[('117_000.bin', 21726)]
# PostingLocsIter: w:manufacturers,
# locs:[('117_000.bin', 22488)]
# PostingLocsIter: w:shapes,
# locs:[('117_000.bin', 22800)]
# PostingLocsIter: w:players,
# locs:[('117_000.bin', 23106)]
# PostingLocsIter: w:monastery,
# locs:[('117_000.bin', 23532)]
# PostingLocsIter: w:classical,
# locs:[('81_000.bin', 0)]
# PostingLocsIter: w:peter,
# locs:[('81_000.bin', 1230)]
# PostingLocsIter: w:kind,
# locs:[('81_000.bin', 2634)]
# PostingLocsIter: w:max,
# locs:[('81_000.bin', 3612)]
# PostingLocsIter: w:karl,
# locs:[('81_000.bin', 4044)]
# PostingLocsIter: w:core,
# locs:[('81_000.bin', 4608)]
# PostingLocsIter: w:patterns,
# locs:[('81_000.bin', 5292)]
# PostingLocsIter: w:structures,
# locs:[('81_000.bin', 5724)]
# PostingLocsIter: w:code,
# locs:[('81_000.bin', 6540)]
# PostingLocsIter: w:organizations,
# locs:[('81_000.bin', 7398)]
# PostingLocsIter: w:gulf,
# locs:[('81_000.bin', 8016)]
# PostingLocsIter: w:suffered,
# locs:[('81_000.bin', 8442)]
# PostingLocsIter: w:agricultural,
# locs:[('81_000.bin', 9204)]
# PostingLocsIter: w:writings,
# locs:[('81_000.bin', 9714)]
# PostingLocsIter: w:tied,
# locs:[('81_000.bin', 10428)]
# PostingLocsIter: w:2020,
# locs:[('81_000.bin', 10752)]
# PostingLocsIter: w:finnish,
# locs:[('81_000.bin', 12084)]
# PostingLocsIter: w:route,
# locs:[('81_000.bin', 12450)]
# PostingLocsIter: w:fate,
# locs:[('81_000.bin', 13146)]
# PostingLocsIter: w:appointed,
# locs:[('81_000.bin', 13482)]
# PostingLocsIter: w:reception,
# locs:[('81_000.bin', 14406)]
# PostingLocsIter: w:visual,
# locs:[('81_000.bin', 14838)]
# PostingLocsIter: w:featured,
# locs:[('81_000.bin', 15318)]
# PostingLocsIter: w:ronald,
# locs:[('81_000.bin', 16146)]
# PostingLocsIter: w:involves,
# locs:[('81_000.bin', 16464)]
# PostingLocsIter: w:dealing,
# locs:[('81_000.bin', 17112)]
# PostingLocsIter: w:tim,
# locs:[('81_000.bin', 17424)]
# PostingLocsIter: w:1933,
# locs:[('81_000.bin', 17778)]
# PostingLocsIter: w:timeline,
# locs:[('81_000.bin', 18594)]
# PostingLocsIter: w:praised,
# locs:[('81_000.bin', 18900)]
# PostingLocsIter: w:politician,
# locs:[('81_000.bin', 19212)]
# PostingLocsIter: w:feast,
# locs:[('81_000.bin', 19806)]
# PostingLocsIter: w:era,
# locs:[('57_000.bin', 0)]
# PostingLocsIter: w:creation,
# locs:[('57_000.bin', 1284)]
# PostingLocsIter: w:latin,
# locs:[('57_000.bin', 2340)]
# PostingLocsIter: w:arose,
# locs:[('57_000.bin', 4002)]
# PostingLocsIter: w:destroy,
# locs:[('57_000.bin', 4338)]
# PostingLocsIter: w:amounts,
# locs:[('57_000.bin', 4758)]
# PostingLocsIter: w:head,
# locs:[('57_000.bin', 5256)]
# PostingLocsIter: w:suggested,
# locs:[('57_000.bin', 6984)]
# PostingLocsIter: w:levels,
# locs:[('57_000.bin', 8268)]
# PostingLocsIter: w:continuing,
# locs:[('57_000.bin', 9138)]
# PostingLocsIter: w:2003,
# locs:[('57_000.bin', 9726)]
# PostingLocsIter: w:succeeded,
# locs:[('57_000.bin', 11322)]
# PostingLocsIter: w:george,
# locs:[('57_000.bin', 12228)]
# PostingLocsIter: w:monument,
# locs:[('57_000.bin', 13866)]
# PostingLocsIter: w:lists,
# locs:[('57_000.bin', 14274)]
# PostingLocsIter: w:topics,
# locs:[('57_000.bin', 14922)]
# PostingLocsIter: w:ordinary,
# locs:[('57_000.bin', 15324)]
# PostingLocsIter: w:1st,
# locs:[('57_000.bin', 15744)]
# PostingLocsIter: w:consequently,
# locs:[('57_000.bin', 16650)]
# PostingLocsIter: w:dying,
# locs:[('57_000.bin', 17232)]
# PostingLocsIter: w:master,
# locs:[('57_000.bin', 17592)]
# PostingLocsIter: w:generations,
# locs:[('57_000.bin', 18294)]
# PostingLocsIter: w:eric,
# locs:[('57_000.bin', 18708)]
# PostingLocsIter: w:treasury,
# locs:[('57_000.bin', 19224)]
# PostingLocsIter: w:correct,
# locs:[('57_000.bin', 19536)]
# PostingLocsIter: w:corresponds,
# locs:[('57_000.bin', 20088)]
# PostingLocsIter: w:applies,
# locs:[('57_000.bin', 20394)]
# PostingLocsIter: w:bass,
# locs:[('57_000.bin', 20784)]
# PostingLocsIter: w:heaven,
# locs:[('57_000.bin', 21198)]
# PostingLocsIter: w:basketball,
# locs:[('57_000.bin', 21552)]
# PostingLocsIter: w:month,
# locs:[('57_000.bin', 22032)]
# PostingLocsIter: w:21st,
# locs:[('79_000.bin', 0)]
# PostingLocsIter: w:example,
# locs:[('79_000.bin', 534)]
# PostingLocsIter: w:additionally,
# locs:[('79_000.bin', 3192)]
# PostingLocsIter: w:discussion,
# locs:[('79_000.bin', 3942)]
# PostingLocsIter: w:began,
# locs:[('79_000.bin', 4506)]
# PostingLocsIter: w:single,
# locs:[('79_000.bin', 6972)]
# PostingLocsIter: w:voice,
# locs:[('79_000.bin', 9030)]
# PostingLocsIter: w:benefit,
# locs:[('79_000.bin', 9798)]
# PostingLocsIter: w:roots,
# locs:[('79_000.bin', 10338)]
# PostingLocsIter: w:scenes,
# locs:[('79_000.bin', 10950)]
# PostingLocsIter: w:article,
# locs:[('79_000.bin', 11334)]
# PostingLocsIter: w:asked,
# locs:[('79_000.bin', 12474)]
# PostingLocsIter: w:applied,
# locs:[('79_000.bin', 13440)]
# PostingLocsIter: w:knowledge,
# locs:[('79_000.bin', 14610)]
# PostingLocsIter: w:waves,
# locs:[('79_000.bin', 15702)]
# PostingLocsIter: w:existed,
# locs:[('79_000.bin', 16038)]
# PostingLocsIter: w:aside,
# locs:[('79_000.bin', 16764)]
# PostingLocsIter: w:bay,
# locs:[('79_000.bin', 17268)]
# PostingLocsIter: w:1861,
# locs:[('79_000.bin', 17940)]
# PostingLocsIter: w:sites,
# locs:[('79_000.bin', 18372)]
# PostingLocsIter: w:warriors,
# locs:[('79_000.bin', 19194)]
# PostingLocsIter: w:enemy,
# locs:[('79_000.bin', 19500)]
# PostingLocsIter: w:carrying,
# locs:[('79_000.bin', 19920)]
# PostingLocsIter: w:card,
# locs:[('79_000.bin', 20580)]
# PostingLocsIter: w:pennsylvania,
# locs:[('79_000.bin', 20910)]
# PostingLocsIter: w:think,
# locs:[('79_000.bin', 21234)]
# PostingLocsIter: w:regular,
# locs:[('79_000.bin', 21864)]
# PostingLocsIter: w:prices,
# locs:[('79_000.bin', 22818)]
# PostingLocsIter: w:continuously,
# locs:[('79_000.bin', 23160)]
# PostingLocsIter: w:puerto,
# locs:[('79_000.bin', 23484)]
# PostingLocsIter: w:diversity,
# locs:[('102_000.bin', 0)]
# PostingLocsIter: w:middle,
# locs:[('102_000.bin', 348)]
# PostingLocsIter: w:soon,
# locs:[('102_000.bin', 2100)]
# PostingLocsIter: w:pushed,
# locs:[('102_000.bin', 3690)]
# PostingLocsIter: w:1864,
# locs:[('102_000.bin', 4080)]
# PostingLocsIter: w:continued,
# locs:[('102_000.bin', 4476)]
# PostingLocsIter: w:remained,
# locs:[('102_000.bin', 6378)]
# PostingLocsIter: w:charges,
# locs:[('102_000.bin', 8100)]
# PostingLocsIter: w:relationships,
# locs:[('102_000.bin', 8556)]
# PostingLocsIter: w:three,
# locs:[('102_000.bin', 9054)]
# PostingLocsIter: w:santa,
# locs:[('102_000.bin', 12792)]
# PostingLocsIter: w:follows,
# locs:[('102_000.bin', 13230)]
# PostingLocsIter: w:experiences,
# locs:[('102_000.bin', 14280)]
# PostingLocsIter: w:decreased,
# locs:[('102_000.bin', 14718)]
# PostingLocsIter: w:officially,
# locs:[('102_000.bin', 15066)]
# PostingLocsIter: w:served,
# locs:[('102_000.bin', 15996)]
# PostingLocsIter: w:costs,
# locs:[('102_000.bin', 17376)]
# PostingLocsIter: w:governor,
# locs:[('102_000.bin', 17808)]
# PostingLocsIter: w:dry,
# locs:[('102_000.bin', 18690)]
# PostingLocsIter: w:transport,
# locs:[('102_000.bin', 19242)]
# PostingLocsIter: w:beauty,
# locs:[('102_000.bin', 19908)]
# PostingLocsIter: w:depicts,
# locs:[('102_000.bin', 20286)]
# PostingLocsIter: w:asia,
# locs:[('102_000.bin', 20652)]
# PostingLocsIter: w:door,
# locs:[('102_000.bin', 21690)]
# PostingLocsIter: w:commissioned,
# locs:[('102_000.bin', 22038)]
# PostingLocsIter: w:thousand,
# locs:[('102_000.bin', 22608)]
# PostingLocsIter: w:database,
# locs:[('102_000.bin', 23214)]
# PostingLocsIter: w:mediterranean,
# locs:[('102_000.bin', 23544)]
# PostingLocsIter: w:order,
# locs:[('38_000.bin', 0)]
# PostingLocsIter: w:france,
# locs:[('38_000.bin', 2850)]
# PostingLocsIter: w:appear,
# locs:[('38_000.bin', 4488)]
# PostingLocsIter: w:point,
# locs:[('38_000.bin', 5940)]
# PostingLocsIter: w:colonies,
# locs:[('38_000.bin', 8184)]
# PostingLocsIter: w:expression,
# locs:[('38_000.bin', 8610)]
# PostingLocsIter: w:activist,
# locs:[('38_000.bin', 9228)]
# PostingLocsIter: w:lives,
# locs:[('38_000.bin', 9726)]
# PostingLocsIter: w:experience,
# locs:[('38_000.bin', 10644)]
# PostingLocsIter: w:learning,
# locs:[('38_000.bin', 11676)]
# PostingLocsIter: w:writes,
# locs:[('38_000.bin', 12372)]
# PostingLocsIter: w:unlike,
# locs:[('38_000.bin', 12954)]
# PostingLocsIter: w:reviews,
# locs:[('38_000.bin', 14136)]
# PostingLocsIter: w:researchers,
# locs:[('38_000.bin', 14448)]
# PostingLocsIter: w:florida,
# locs:[('38_000.bin', 15066)]
# PostingLocsIter: w:alexander,
# locs:[('38_000.bin', 15534)]
# PostingLocsIter: w:soldiers,
# locs:[('38_000.bin', 16746)]
# PostingLocsIter: w:storm,
# locs:[('38_000.bin', 17544)]
# PostingLocsIter: w:doctor,
# locs:[('38_000.bin', 17880)]
# PostingLocsIter: w:entertainment,
# locs:[('38_000.bin', 18366)]
# PostingLocsIter: w:offers,
# locs:[('38_000.bin', 18828)]
# PostingLocsIter: w:post,
# locs:[('38_000.bin', 19416)]
# PostingLocsIter: w:harry,
# locs:[('38_000.bin', 20178)]
# PostingLocsIter: w:behalf,
# locs:[('38_000.bin', 20634)]
# PostingLocsIter: w:songs,
# locs:[('38_000.bin', 21054)]
# PostingLocsIter: w:isaac,
# locs:[('38_000.bin', 21534)]
# PostingLocsIter: w:discovery,
# locs:[('38_000.bin', 21840)]
# PostingLocsIter: w:getting,
# locs:[('38_000.bin', 22650)]
# PostingLocsIter: w:afghanistan,
# locs:[('38_000.bin', 23076)]
# PostingLocsIter: w:netherlands,
# locs:[('38_000.bin', 23454)]
# PostingLocsIter: w:hebrew,
# locs:[('38_000.bin', 24042)]
# PostingLocsIter: w:footballer,
# locs:[('38_000.bin', 24378)]
# PostingLocsIter: w:meet,
# locs:[('54_000.bin', 0)]
# PostingLocsIter: w:components,
# locs:[('54_000.bin', 852)]
# PostingLocsIter: w:struggle,
# locs:[('54_000.bin', 1566)]
# PostingLocsIter: w:grew,
# locs:[('54_000.bin', 2046)]
# PostingLocsIter: w:result,
# locs:[('54_000.bin', 3036)]
# PostingLocsIter: w:worked,
# locs:[('54_000.bin', 5454)]
# PostingLocsIter: w:web,
# locs:[('54_000.bin', 6684)]
# PostingLocsIter: w:women,
# locs:[('54_000.bin', 7116)]
# PostingLocsIter: w:published,
# locs:[('54_000.bin', 8424)]
# PostingLocsIter: w:sale,
# locs:[('54_000.bin', 10692)]
# PostingLocsIter: w:characteristic,
# locs:[('54_000.bin', 11130)]
# PostingLocsIter: w:understanding,
# locs:[('54_000.bin', 11730)]
# PostingLocsIter: w:reducing,
# locs:[('54_000.bin', 12606)]
# PostingLocsIter: w:concluded,
# locs:[('54_000.bin', 13128)]
# PostingLocsIter: w:rule,
# locs:[('54_000.bin', 13878)]
# PostingLocsIter: w:dating,
# locs:[('54_000.bin', 15192)]
# PostingLocsIter: w:prior,
# locs:[('54_000.bin', 15828)]
# PostingLocsIter: w:effort,
# locs:[('54_000.bin', 17214)]
# PostingLocsIter: w:film,
# locs:[('54_000.bin', 18084)]
# PostingLocsIter: w:campus,
# locs:[('54_000.bin', 19602)]
# PostingLocsIter: w:learned,
# locs:[('54_000.bin', 19914)]
# PostingLocsIter: w:return,
# locs:[('54_000.bin', 20616)]
# PostingLocsIter: w:wall,
# locs:[('54_000.bin', 22272)]
# PostingLocsIter: w:chapter,
# locs:[('54_000.bin', 23040)]
# PostingLocsIter: w:royal,
# locs:[('54_000.bin', 23700)]
# PostingLocsIter: w:launched,
# locs:[('54_000.bin', 25344)]
# PostingLocsIter: w:plot,
# locs:[('54_000.bin', 26274)]
# PostingLocsIter: w:allen,
# locs:[('54_000.bin', 26820)]
# PostingLocsIter: w:capability,
# locs:[('54_000.bin', 27288)]
# PostingLocsIter: w:biology,
# locs:[('54_000.bin', 27606)]
# PostingLocsIter: w:indicating,
# locs:[('54_000.bin', 27918)]
# PostingLocsIter: w:supposed,
# locs:[('54_000.bin', 28392)]
# PostingLocsIter: w:eds,
# locs:[('54_000.bin', 28836)]
# PostingLocsIter: w:performing,
# locs:[('54_000.bin', 29142)]
# PostingLocsIter: w:score,
# locs:[('54_000.bin', 29670)]
# PostingLocsIter: w:1959,
# locs:[('54_000.bin', 30006)]
# PostingLocsIter: w:termed,
# locs:[('54_000.bin', 30798)]
# PostingLocsIter: w:1845,
# locs:[('54_000.bin', 31242)]
# PostingLocsIter: w:guilty,
# locs:[('54_000.bin', 31596)]
# PostingLocsIter: w:ideal,
# locs:[('14_000.bin', 0)]
# PostingLocsIter: w:far,
# locs:[('14_000.bin', 486)]
# PostingLocsIter: w:henry,
# locs:[('14_000.bin', 2316)]
# PostingLocsIter: w:evil,
# locs:[('14_000.bin', 3726)]
# PostingLocsIter: w:symbols,
# locs:[('14_000.bin', 4038)]
# PostingLocsIter: w:connect,
# locs:[('14_000.bin', 4632)]
# PostingLocsIter: w:possibility,
# locs:[('14_000.bin', 4938)]
# PostingLocsIter: w:relevant,
# locs:[('14_000.bin', 5556)]
# PostingLocsIter: w:concrete,
# locs:[('14_000.bin', 5904)]
# PostingLocsIter: w:derives,
# locs:[('14_000.bin', 6240)]
# PostingLocsIter: w:thousands,
# locs:[('14_000.bin', 6672)]
# PostingLocsIter: w:membership,
# locs:[('14_000.bin', 7530)]
# PostingLocsIter: w:visitors,
# locs:[('14_000.bin', 7872)]
# PostingLocsIter: w:requires,
# locs:[('14_000.bin', 8262)]
# PostingLocsIter: w:gregory,
# locs:[('14_000.bin', 9012)]
# PostingLocsIter: w:evening,
# locs:[('14_000.bin', 9420)]
# PostingLocsIter: w:couple,
# locs:[('14_000.bin', 9804)]
# PostingLocsIter: w:alliance,
# locs:[('14_000.bin', 10224)]
# PostingLocsIter: w:enormous,
# locs:[('14_000.bin', 10788)]
# PostingLocsIter: w:revised,
# locs:[('14_000.bin', 11178)]
# PostingLocsIter: w:jonathan,
# locs:[('14_000.bin', 11646)]
# PostingLocsIter: w:1985,
# locs:[('14_000.bin', 12078)]
# PostingLocsIter: w:movie,
# locs:[('14_000.bin', 13176)]
# PostingLocsIter: w:calendar,
# locs:[('14_000.bin', 13698)]
# PostingLocsIter: w:org,
# locs:[('14_000.bin', 14070)]
# PostingLocsIter: w:bulk,
# locs:[('14_000.bin', 14454)]
# PostingLocsIter: w:virtual,
# locs:[('14_000.bin', 14814)]
# PostingLocsIter: w:accessible,
# locs:[('14_000.bin', 15150)]
# PostingLocsIter: w:portuguese,
# locs:[('14_000.bin', 15480)]
# PostingLocsIter: w:separated,
# locs:[('23_000.bin', 0)]
# PostingLocsIter: w:elements,
# locs:[('23_000.bin', 792)]
# PostingLocsIter: w:transition,
# locs:[('23_000.bin', 2028)]
# PostingLocsIter: w:spectrum,
# locs:[('23_000.bin', 2478)]
# PostingLocsIter: w:relatively,
# locs:[('23_000.bin', 2892)]
# PostingLocsIter: w:feel,
# locs:[('23_000.bin', 4200)]
# PostingLocsIter: w:users,
# locs:[('23_000.bin', 4626)]
# PostingLocsIter: w:disputed,
# locs:[('23_000.bin', 5064)]
# PostingLocsIter: w:proposed,
# locs:[('23_000.bin', 5538)]
# PostingLocsIter: w:maintaining,
# locs:[('23_000.bin', 6882)]
# PostingLocsIter: w:interactions,
# locs:[('23_000.bin', 7320)]
# PostingLocsIter: w:initiated,
# locs:[('23_000.bin', 7644)]
# PostingLocsIter: w:flat,
# locs:[('23_000.bin', 8124)]
# PostingLocsIter: w:1000,
# locs:[('23_000.bin', 8664)]
# PostingLocsIter: w:1928,
# locs:[('23_000.bin', 9126)]
# PostingLocsIter: w:1964,
# locs:[('23_000.bin', 9924)]
# PostingLocsIter: w:pacific,
# locs:[('23_000.bin', 10926)]
# PostingLocsIter: w:spoken,
# locs:[('23_000.bin', 11532)]
# PostingLocsIter: w:routes,
# locs:[('23_000.bin', 12072)]
# PostingLocsIter: w:says,
# locs:[('23_000.bin', 12462)]
# PostingLocsIter: w:virginia,
# locs:[('23_000.bin', 13308)]
# PostingLocsIter: w:short,
# locs:[('23_000.bin', 13878)]
# PostingLocsIter: w:grandson,
# locs:[('23_000.bin', 15996)]
# PostingLocsIter: w:1856,
# locs:[('23_000.bin', 16320)]
# PostingLocsIter: w:possession,
# locs:[('23_000.bin', 16668)]
# PostingLocsIter: w:rendered,
# locs:[('23_000.bin', 17118)]
# PostingLocsIter: w:finding,
# locs:[('23_000.bin', 17466)]
# PostingLocsIter: w:olympic,
# locs:[('23_000.bin', 18054)]
# PostingLocsIter: w:unsuccessful,
# locs:[('23_000.bin', 18402)]
# PostingLocsIter: w:1905,
# locs:[('23_000.bin', 18822)]
# PostingLocsIter: w:350,
# locs:[('23_000.bin', 19458)]
# PostingLocsIter: w:valid,
# locs:[('23_000.bin', 19782)]
# PostingLocsIter: w:rugby,
# locs:[('23_000.bin', 20172)]
# PostingLocsIter: w:bring,
# locs:[('116_000.bin', 0)]
# PostingLocsIter: w:inspired,
# locs:[('116_000.bin', 876)]
# PostingLocsIter: w:myth,
# locs:[('116_000.bin', 1770)]
# PostingLocsIter: w:turned,
# locs:[('116_000.bin', 2148)]
# PostingLocsIter: w:implemented,
# locs:[('116_000.bin', 3420)]
# PostingLocsIter: w:contributed,
# locs:[('116_000.bin', 3900)]
# PostingLocsIter: w:center,
# locs:[('116_000.bin', 4566)]
# PostingLocsIter: w:quickly,
# locs:[('116_000.bin', 6222)]
# PostingLocsIter: w:implementation,
# locs:[('116_000.bin', 7320)]
# PostingLocsIter: w:employment,
# locs:[('116_000.bin', 7626)]
# PostingLocsIter: w:articles,
# locs:[('116_000.bin', 8004)]
# PostingLocsIter: w:warm,
# locs:[('116_000.bin', 9030)]
# PostingLocsIter: w:georgia,
# locs:[('116_000.bin', 9354)]
# PostingLocsIter: w:lost,
# locs:[('116_000.bin', 9858)]
# PostingLocsIter: w:retained,
# locs:[('116_000.bin', 11682)]
# PostingLocsIter: w:1950,
# locs:[('116_000.bin', 12258)]
# PostingLocsIter: w:1979,
# locs:[('116_000.bin', 13080)]
# PostingLocsIter: w:hidden,
# locs:[('116_000.bin', 14166)]
# PostingLocsIter: w:attempt,
# locs:[('116_000.bin', 14568)]
# PostingLocsIter: w:1866,
# locs:[('116_000.bin', 15996)]
# PostingLocsIter: w:holidays,
# locs:[('116_000.bin', 16392)]
# PostingLocsIter: w:czech,
# locs:[('116_000.bin', 16860)]
# PostingLocsIter: w:joining,
# locs:[('116_000.bin', 17304)]
# PostingLocsIter: w:buy,
# locs:[('116_000.bin', 17634)]
# PostingLocsIter: w:iranian,
# locs:[('116_000.bin', 17958)]
# PostingLocsIter: w:sam,
# locs:[('116_000.bin', 18312)]
# PostingLocsIter: w:singer-songwriter,
# locs:[('116_000.bin', 18642)]
# PostingLocsIter: w:turn,
# locs:[('26_000.bin', 0)]
# PostingLocsIter: w:greece,
# locs:[('26_000.bin', 1374)]
# PostingLocsIter: w:said,
# locs:[('26_000.bin', 2214)]
# PostingLocsIter: w:become,
# locs:[('26_000.bin', 4644)]
# PostingLocsIter: w:1880,
# locs:[('26_000.bin', 7224)]
# PostingLocsIter: w:east,
# locs:[('26_000.bin', 7692)]
# PostingLocsIter: w:successful,
# locs:[('26_000.bin', 9678)]
# PostingLocsIter: w:attacked,
# locs:[('26_000.bin', 11058)]
# PostingLocsIter: w:pronounced,
# locs:[('26_000.bin', 11694)]
# PostingLocsIter: w:affected,
# locs:[('26_000.bin', 12048)]
# PostingLocsIter: w:2015,
# locs:[('26_000.bin', 12834)]
# PostingLocsIter: w:front,
# locs:[('26_000.bin', 14400)]
# PostingLocsIter: w:1990s,
# locs:[('26_000.bin', 15666)]
# PostingLocsIter: w:situations,
# locs:[('26_000.bin', 16482)]
# PostingLocsIter: w:minimum,
# locs:[('26_000.bin', 16842)]
# PostingLocsIter: w:radiation,
# locs:[('26_000.bin', 17310)]
# PostingLocsIter: w:perhaps,
# locs:[('26_000.bin', 17652)]
# PostingLocsIter: w:clear,
# locs:[('26_000.bin', 18774)]
# PostingLocsIter: w:variant,
# locs:[('26_000.bin', 20040)]
# PostingLocsIter: w:sign,
# locs:[('26_000.bin', 20526)]
# PostingLocsIter: w:vote,
# locs:[('26_000.bin', 21438)]
# PostingLocsIter: w:raising,
# locs:[('26_000.bin', 21918)]
# PostingLocsIter: w:11th,
# locs:[('26_000.bin', 22272)]
# PostingLocsIter: w:painting,
# locs:[('26_000.bin', 22752)]
# PostingLocsIter: w:becoming,
# locs:[('26_000.bin', 23310)]
# PostingLocsIter: w:israel,
# locs:[('26_000.bin', 24600)]
# PostingLocsIter: w:finished,
# locs:[('26_000.bin', 25080)]
# PostingLocsIter: w:sole,
# locs:[('26_000.bin', 25656)]
# PostingLocsIter: w:thirteen,
# locs:[('26_000.bin', 26142)]
# PostingLocsIter: w:separately,
# locs:[('26_000.bin', 26454)]
# PostingLocsIter: w:got,
# locs:[('26_000.bin', 26832)]
# PostingLocsIter: w:winner,
# locs:[('26_000.bin', 27354)]
# PostingLocsIter: w:bruce,
# locs:[('26_000.bin', 27684)]
# PostingLocsIter: w:mainland,
# locs:[('26_000.bin', 28200)]
# PostingLocsIter: w:user,
# locs:[('26_000.bin', 28524)]
# PostingLocsIter: w:happened,
# locs:[('26_000.bin', 28842)]
# PostingLocsIter: w:society,
# locs:[('0_000.bin', 0)]
# PostingLocsIter: w:largely,
# locs:[('0_000.bin', 1686)]
# PostingLocsIter: w:organisation,
# locs:[('0_000.bin', 3024)]
# PostingLocsIter: w:actions,
# locs:[('0_000.bin', 3396)]
# PostingLocsIter: w:carried,
# locs:[('0_000.bin', 4284)]
# PostingLocsIter: w:prevent,
# locs:[('0_000.bin', 5478)]
# PostingLocsIter: w:key,
# locs:[('0_000.bin', 6636)]
# PostingLocsIter: w:biological,
# locs:[('0_000.bin', 7908)]
# PostingLocsIter: w:secondary,
# locs:[('0_000.bin', 8346)]
# PostingLocsIter: w:leaving,
# locs:[('0_000.bin', 9114)]
# PostingLocsIter: w:show,
# locs:[('0_000.bin', 10374)]
# PostingLocsIter: w:explained,
# locs:[('0_000.bin', 12258)]
# PostingLocsIter: w:participants,
# locs:[('0_000.bin', 12906)]
# PostingLocsIter: w:received,
# locs:[('0_000.bin', 13218)]
# PostingLocsIter: w:dynamic,
# locs:[('0_000.bin', 15054)]
# PostingLocsIter: w:preceding,
# locs:[('0_000.bin', 15372)]
# PostingLocsIter: w:colour,
# locs:[('0_000.bin', 15714)]
# PostingLocsIter: w:index,
# locs:[('0_000.bin', 16032)]
# PostingLocsIter: w:election,
# locs:[('0_000.bin', 16512)]
# PostingLocsIter: w:places,
# locs:[('0_000.bin', 17148)]
# PostingLocsIter: w:coast,
# locs:[('0_000.bin', 18456)]
# PostingLocsIter: w:record,
# locs:[('0_000.bin', 19512)]
# PostingLocsIter: w:powers,
# locs:[('0_000.bin', 20850)]
# PostingLocsIter: w:7th,
# locs:[('0_000.bin', 21588)]
# PostingLocsIter: w:profile,
# locs:[('0_000.bin', 22134)]
# PostingLocsIter: w:thing,
# locs:[('0_000.bin', 22494)]
# PostingLocsIter: w:treatise,
# locs:[('0_000.bin', 22986)]
# PostingLocsIter: w:demonstration,
# locs:[('0_000.bin', 23346)]
# PostingLocsIter: w:emergency,
# locs:[('0_000.bin', 23658)]
# PostingLocsIter: w:1902,
# locs:[('0_000.bin', 24000)]
# PostingLocsIter: w:arab,
# locs:[('0_000.bin', 24606)]
# PostingLocsIter: w:periods,
# locs:[('0_000.bin', 25044)]
# PostingLocsIter: w:pages,
# locs:[('0_000.bin', 25650)]
# PostingLocsIter: w:turkey,
# locs:[('0_000.bin', 26118)]
# PostingLocsIter: w:criticism,
# locs:[('36_000.bin', 0)]
# PostingLocsIter: w:engaged,
# locs:[('36_000.bin', 630)]
# PostingLocsIter: w:specific,
# locs:[('36_000.bin', 1212)]
# PostingLocsIter: w:adding,
# locs:[('36_000.bin', 2664)]
# PostingLocsIter: w:read,
# locs:[('36_000.bin', 3456)]
# PostingLocsIter: w:distinguished,
# locs:[('36_000.bin', 4470)]
# PostingLocsIter: w:systematic,
# locs:[('36_000.bin', 5064)]
# PostingLocsIter: w:closely,
# locs:[('36_000.bin', 5490)]
# PostingLocsIter: w:game,
# locs:[('36_000.bin', 6462)]
# PostingLocsIter: w:girls,
# locs:[('36_000.bin', 7434)]
# PostingLocsIter: w:option,
# locs:[('36_000.bin', 7764)]
# PostingLocsIter: w:ruled,
# locs:[('36_000.bin', 8082)]
# PostingLocsIter: w:memory,
# locs:[('36_000.bin', 8826)]
# PostingLocsIter: w:defined,
# locs:[('36_000.bin', 9678)]
# PostingLocsIter: w:top,
# locs:[('36_000.bin', 10962)]
# PostingLocsIter: w:texts,
# locs:[('36_000.bin', 12318)]
# PostingLocsIter: w:carolina,
# locs:[('36_000.bin', 12942)]
# PostingLocsIter: w:grace,
# locs:[('36_000.bin', 13290)]
# PostingLocsIter: w:20th-century,
# locs:[('36_000.bin', 13626)]
# PostingLocsIter: w:pictures,
# locs:[('36_000.bin', 14214)]
# PostingLocsIter: w:standing,
# locs:[('36_000.bin', 14652)]
# PostingLocsIter: w:revolt,
# locs:[('36_000.bin', 15300)]
# PostingLocsIter: w:jason,
# locs:[('36_000.bin', 15714)]
# PostingLocsIter: w:areas,
# locs:[('39_000.bin', 0)]
# PostingLocsIter: w:united,
# locs:[('39_000.bin', 1494)]
# PostingLocsIter: w:associate,
# locs:[('39_000.bin', 4476)]
# PostingLocsIter: w:england,
# locs:[('39_000.bin', 4890)]
# PostingLocsIter: w:quite,
# locs:[('39_000.bin', 6270)]
# PostingLocsIter: w:men,
# locs:[('39_000.bin', 7206)]
# PostingLocsIter: w:months,
# locs:[('39_000.bin', 8940)]
# PostingLocsIter: w:granted,
# locs:[('39_000.bin', 10368)]
# PostingLocsIter: w:agents,
# locs:[('39_000.bin', 11160)]
# PostingLocsIter: w:techniques,
# locs:[('39_000.bin', 11580)]
# PostingLocsIter: w:consistent,
# locs:[('39_000.bin', 12450)]
# PostingLocsIter: w:visible,
# locs:[('39_000.bin', 13014)]
# PostingLocsIter: w:italy,
# locs:[('39_000.bin', 13680)]
# PostingLocsIter: w:heart,
# locs:[('39_000.bin', 14874)]
# PostingLocsIter: w:legislation,
# locs:[('39_000.bin', 15804)]
# PostingLocsIter: w:hired,
# locs:[('39_000.bin', 16164)]
# PostingLocsIter: w:stopped,
# locs:[('39_000.bin', 16548)]
# PostingLocsIter: w:realized,
# locs:[('39_000.bin', 17028)]
# PostingLocsIter: w:stages,
# locs:[('39_000.bin', 17472)]
# PostingLocsIter: w:themes,
# locs:[('39_000.bin', 18036)]
# PostingLocsIter: w:spot,
# locs:[('39_000.bin', 18474)]
# PostingLocsIter: w:crime,
# locs:[('39_000.bin', 18804)]
# PostingLocsIter: w:journalist,
# locs:[('39_000.bin', 19260)]
# PostingLocsIter: w:cemetery,
# locs:[('39_000.bin', 19902)]
# PostingLocsIter: w:fairly,
# locs:[('39_000.bin', 20238)]
# PostingLocsIter: w:page,
# locs:[('39_000.bin', 20628)]
# PostingLocsIter: w:abroad,
# locs:[('39_000.bin', 21390)]
# PostingLocsIter: w:1916,
# locs:[('39_000.bin', 21738)]
# PostingLocsIter: w:banned,
# locs:[('39_000.bin', 22374)]
# PostingLocsIter: w:alex,
# locs:[('39_000.bin', 22758)]
# PostingLocsIter: w:chancellor,
# locs:[('39_000.bin', 23070)]
# PostingLocsIter: w:human,
# locs:[('16_000.bin', 0)]
# PostingLocsIter: w:exact,
# locs:[('16_000.bin', 1926)]
# PostingLocsIter: w:one,
# locs:[('16_000.bin', 2556)]
# PostingLocsIter: w:cities,
# locs:[('16_000.bin', 7470)]
# PostingLocsIter: w:followers,
# locs:[('16_000.bin', 8496)]
# PostingLocsIter: w:russian,
# locs:[('16_000.bin', 9006)]
# PostingLocsIter: w:japanese,
# locs:[('16_000.bin', 10218)]
# PostingLocsIter: w:mexico,
# locs:[('16_000.bin', 11160)]
# PostingLocsIter: w:1840,
# locs:[('16_000.bin', 11874)]
# PostingLocsIter: w:practiced,
# locs:[('16_000.bin', 12252)]
# PostingLocsIter: w:alternative,
# locs:[('16_000.bin', 12570)]
# PostingLocsIter: w:whilst,
# locs:[('16_000.bin', 13650)]
# PostingLocsIter: w:idea,
# locs:[('16_000.bin', 13986)]
# PostingLocsIter: w:interests,
# locs:[('16_000.bin', 15234)]
# PostingLocsIter: w:theme,
# locs:[('16_000.bin', 15726)]
# PostingLocsIter: w:classes,
# locs:[('16_000.bin', 16266)]
# PostingLocsIter: w:range,
# locs:[('16_000.bin', 16866)]
# PostingLocsIter: w:buildings,
# locs:[('16_000.bin', 18576)]
# PostingLocsIter: w:compounds,
# locs:[('16_000.bin', 19242)]
# PostingLocsIter: w:park,
# locs:[('16_000.bin', 19596)]
# PostingLocsIter: w:houston,
# locs:[('16_000.bin', 20496)]
# PostingLocsIter: w:lee,
# locs:[('16_000.bin', 20802)]
# PostingLocsIter: w:fighting,
# locs:[('16_000.bin', 21456)]
# PostingLocsIter: w:hundred,
# locs:[('16_000.bin', 22212)]
# PostingLocsIter: w:withdrew,
# locs:[('16_000.bin', 23172)]
# PostingLocsIter: w:famous,
# locs:[('16_000.bin', 23514)]
# PostingLocsIter: w:1839,
# locs:[('16_000.bin', 24984)]
# PostingLocsIter: w:attended,
# locs:[('16_000.bin', 25308)]
# PostingLocsIter: w:collections,
# locs:[('16_000.bin', 25908)]
# PostingLocsIter: w:translated,
# locs:[('16_000.bin', 26304)]
# PostingLocsIter: w:1995,
# locs:[('16_000.bin', 27054)]
# PostingLocsIter: w:designer,
# locs:[('16_000.bin', 28476)]
# PostingLocsIter: w:danish,
# locs:[('16_000.bin', 29052)]
# PostingLocsIter: w:saints,
# locs:[('16_000.bin', 29574)]
# PostingLocsIter: w:civilian,
# locs:[('16_000.bin', 29940)]
# PostingLocsIter: w:floor,
# locs:[('16_000.bin', 30264)]
# PostingLocsIter: w:etymology,
# locs:[('34_000.bin', 0)]
# PostingLocsIter: w:generation,
# locs:[('34_000.bin', 738)]
# PostingLocsIter: w:christian,
# locs:[('34_000.bin', 1530)]
# PostingLocsIter: w:ancestors,
# locs:[('34_000.bin', 3060)]
# PostingLocsIter: w:explicitly,
# locs:[('34_000.bin', 3384)]
# PostingLocsIter: w:promoting,
# locs:[('34_000.bin', 3894)]
# PostingLocsIter: w:open,
# locs:[('34_000.bin', 4260)]
# PostingLocsIter: w:produced,
# locs:[('34_000.bin', 5838)]
# PostingLocsIter: w:begin,
# locs:[('34_000.bin', 7734)]
# PostingLocsIter: w:feeling,
# locs:[('34_000.bin', 8658)]
# PostingLocsIter: w:seem,
# locs:[('34_000.bin', 8982)]
# PostingLocsIter: w:features,
# locs:[('34_000.bin', 9654)]
# PostingLocsIter: w:problems,
# locs:[('34_000.bin', 11124)]
# PostingLocsIter: w:reported,
# locs:[('34_000.bin', 12324)]
# PostingLocsIter: w:comparison,
# locs:[('34_000.bin', 13704)]
# PostingLocsIter: w:impact,
# locs:[('34_000.bin', 14466)]
# PostingLocsIter: w:mentioned,
# locs:[('34_000.bin', 15354)]
# PostingLocsIter: w:project,
# locs:[('34_000.bin', 16416)]
# PostingLocsIter: w:8th,
# locs:[('34_000.bin', 17850)]
# PostingLocsIter: w:greatest,
# locs:[('34_000.bin', 18390)]
# PostingLocsIter: w:reached,
# locs:[('34_000.bin', 19284)]
# PostingLocsIter: w:division,
# locs:[('34_000.bin', 20556)]
# PostingLocsIter: w:headed,
# locs:[('34_000.bin', 21516)]
# PostingLocsIter: w:summary,
# locs:[('34_000.bin', 21930)]
# PostingLocsIter: w:oliver,
# locs:[('34_000.bin', 22272)]
# PostingLocsIter: w:experimental,
# locs:[('34_000.bin', 22614)]
# PostingLocsIter: w:exchange,
# locs:[('34_000.bin', 23094)]
# PostingLocsIter: w:1951,
# locs:[('34_000.bin', 23916)]
# PostingLocsIter: w:winners,
# locs:[('34_000.bin', 24654)]
# PostingLocsIter: w:1967,
# locs:[('34_000.bin', 24978)]
# PostingLocsIter: w:input,
# locs:[('34_000.bin', 25968)]
# PostingLocsIter: w:inner,
# locs:[('34_000.bin', 26358)]
# PostingLocsIter: w:watch,
# locs:[('34_000.bin', 26892)]
# PostingLocsIter: w:musician,
# locs:[('34_000.bin', 27210)]
# PostingLocsIter: w:israeli,
# locs:[('34_000.bin', 27714)]
# PostingLocsIter: w:theory,
# locs:[('86_000.bin', 0)]
# PostingLocsIter: w:beginning,
# locs:[('86_000.bin', 1290)]
# PostingLocsIter: w:cannot,
# locs:[('86_000.bin', 3240)]
# PostingLocsIter: w:founded,
# locs:[('86_000.bin', 4440)]
# PostingLocsIter: w:mutual,
# locs:[('86_000.bin', 6120)]
# PostingLocsIter: w:along,
# locs:[('86_000.bin', 6516)]
# PostingLocsIter: w:technology,
# locs:[('86_000.bin', 9204)]
# PostingLocsIter: w:matters,
# locs:[('86_000.bin', 10542)]
# PostingLocsIter: w:speech,
# locs:[('86_000.bin', 11052)]
# PostingLocsIter: w:steps,
# locs:[('86_000.bin', 11832)]
# PostingLocsIter: w:modified,
# locs:[('86_000.bin', 12306)]
# PostingLocsIter: w:2010,
# locs:[('86_000.bin', 12996)]
# PostingLocsIter: w:jean,
# locs:[('86_000.bin', 14790)]
# PostingLocsIter: w:outer,
# locs:[('86_000.bin', 15558)]
# PostingLocsIter: w:net,
# locs:[('86_000.bin', 16038)]
# PostingLocsIter: w:knight,
# locs:[('86_000.bin', 16620)]
# PostingLocsIter: w:onwards,
# locs:[('86_000.bin', 16938)]
# PostingLocsIter: w:building,
# locs:[('86_000.bin', 17304)]
# PostingLocsIter: w:eve,
# locs:[('86_000.bin', 18756)]
# PostingLocsIter: w:branches,
# locs:[('86_000.bin', 19116)]
# PostingLocsIter: w:tom,
# locs:[('86_000.bin', 19620)]
# PostingLocsIter: w:companion,
# locs:[('86_000.bin', 20202)]
# PostingLocsIter: w:directed,
# locs:[('86_000.bin', 20640)]
# PostingLocsIter: w:shares,
# locs:[('86_000.bin', 21432)]
# PostingLocsIter: w:antonio,
# locs:[('86_000.bin', 21780)]
# PostingLocsIter: w:navy,
# locs:[('86_000.bin', 22170)]
# PostingLocsIter: w:returning,
# locs:[('86_000.bin', 22956)]
# PostingLocsIter: w:sight,
# locs:[('86_000.bin', 23532)]
# PostingLocsIter: w:dates,
# locs:[('86_000.bin', 23892)]
# PostingLocsIter: w:radio,
# locs:[('86_000.bin', 24540)]
# PostingLocsIter: w:awarded,
# locs:[('86_000.bin', 25632)]
# PostingLocsIter: w:fleet,
# locs:[('86_000.bin', 26424)]
# PostingLocsIter: w:cancer,
# locs:[('86_000.bin', 26916)]
# PostingLocsIter: w:charter,
# locs:[('86_000.bin', 27258)]
# PostingLocsIter: w:bbc,
# locs:[('86_000.bin', 27570)]
# PostingLocsIter: w:village,
# locs:[('86_000.bin', 28188)]
# PostingLocsIter: w:consist,
# locs:[('86_000.bin', 28872)]
# PostingLocsIter: w:flow,
# locs:[('86_000.bin', 29304)]
# PostingLocsIter: w:binding,
# locs:[('86_000.bin', 29868)]
# PostingLocsIter: w:without,
# locs:[('28_000.bin', 0)]
# PostingLocsIter: w:goods,
# locs:[('28_000.bin', 2634)]
# PostingLocsIter: w:focused,
# locs:[('28_000.bin', 3174)]
# PostingLocsIter: w:relationship,
# locs:[('28_000.bin', 3852)]
# PostingLocsIter: w:directly,
# locs:[('28_000.bin', 5106)]
# PostingLocsIter: w:improving,
# locs:[('28_000.bin', 6648)]
# PostingLocsIter: w:1996,
# locs:[('28_000.bin', 6954)]
# PostingLocsIter: w:heinrich,
# locs:[('28_000.bin', 8430)]
# PostingLocsIter: w:materials,
# locs:[('28_000.bin', 8748)]
# PostingLocsIter: w:irish,
# locs:[('28_000.bin', 9558)]
# PostingLocsIter: w:cup,
# locs:[('28_000.bin', 10266)]
# PostingLocsIter: w:colonial,
# locs:[('28_000.bin', 10578)]
# PostingLocsIter: w:residents,
# locs:[('28_000.bin', 11004)]
# PostingLocsIter: w:disease,
# locs:[('28_000.bin', 11376)]
# PostingLocsIter: w:jones,
# locs:[('28_000.bin', 12084)]
# PostingLocsIter: w:1992,
# locs:[('28_000.bin', 12612)]
# PostingLocsIter: w:sculpture,
# locs:[('28_000.bin', 13938)]
# PostingLocsIter: w:1895,
# locs:[('28_000.bin', 14316)]
# PostingLocsIter: w:films,
# locs:[('28_000.bin', 14856)]
# PostingLocsIter: w:alive,
# locs:[('28_000.bin', 15444)]
# PostingLocsIter: w:lacking,
# locs:[('28_000.bin', 15840)]
# PostingLocsIter: w:sacred,
# locs:[('28_000.bin', 16200)]
# PostingLocsIter: w:architect,
# locs:[('28_000.bin', 16638)]
# PostingLocsIter: w:nobel,
# locs:[('28_000.bin', 17268)]
# PostingLocsIter: w:succeed,
# locs:[('28_000.bin', 17850)]
# PostingLocsIter: w:programming,
# locs:[('28_000.bin', 18156)]
# PostingLocsIter: w:using,
# locs:[('50_000.bin', 0)]
# PostingLocsIter: w:exist,
# locs:[('50_000.bin', 2508)]
# PostingLocsIter: w:federation,
# locs:[('50_000.bin', 3546)]
# PostingLocsIter: w:october,
# locs:[('50_000.bin', 3876)]
# PostingLocsIter: w:series,
# locs:[('50_000.bin', 5742)]
# PostingLocsIter: w:eliminate,
# locs:[('50_000.bin', 8004)]
# PostingLocsIter: w:representative,
# locs:[('50_000.bin', 8364)]
# PostingLocsIter: w:course,
# locs:[('50_000.bin', 8874)]
# PostingLocsIter: w:majority,
# locs:[('50_000.bin', 9858)]
# PostingLocsIter: w:instead,
# locs:[('50_000.bin', 11142)]
# PostingLocsIter: w:reliable,
# locs:[('50_000.bin', 13356)]
# PostingLocsIter: w:difference,
# locs:[('50_000.bin', 13716)]
# PostingLocsIter: w:unusual,
# locs:[('50_000.bin', 14634)]
# PostingLocsIter: w:earth's,
# locs:[('50_000.bin', 15222)]
# PostingLocsIter: w:spite,
# locs:[('50_000.bin', 15582)]
# PostingLocsIter: w:foreign,
# locs:[('50_000.bin', 15918)]
# PostingLocsIter: w:dominated,
# locs:[('50_000.bin', 17154)]
# PostingLocsIter: w:accounts,
# locs:[('50_000.bin', 17718)]
# PostingLocsIter: w:huge,
# locs:[('50_000.bin', 18336)]
# PostingLocsIter: w:access,
# locs:[('50_000.bin', 18906)]
# PostingLocsIter: w:steve,
# locs:[('50_000.bin', 19806)]
# PostingLocsIter: w:worship,
# locs:[('50_000.bin', 20298)]
# PostingLocsIter: w:selling,
# locs:[('50_000.bin', 20646)]
# PostingLocsIter: w:description,
# locs:[('50_000.bin', 21060)]
# PostingLocsIter: w:piece,
# locs:[('50_000.bin', 22074)]
# PostingLocsIter: w:arthur,
# locs:[('50_000.bin', 22698)]
# PostingLocsIter: w:ann,
# locs:[('50_000.bin', 23376)]
# PostingLocsIter: w:appeared,
# locs:[('50_000.bin', 23736)]
# PostingLocsIter: w:agent,
# locs:[('50_000.bin', 25068)]
# PostingLocsIter: w:soft,
# locs:[('50_000.bin', 25596)]
# PostingLocsIter: w:silver,
# locs:[('50_000.bin', 26010)]
# PostingLocsIter: w:introduction,
# locs:[('50_000.bin', 26808)]
# PostingLocsIter: w:trip,
# locs:[('50_000.bin', 27876)]
# PostingLocsIter: w:brazilian,
# locs:[('50_000.bin', 28290)]
# PostingLocsIter: w:origin,
# locs:[('55_000.bin', 0)]
# PostingLocsIter: w:party,
# locs:[('55_000.bin', 1278)]
# PostingLocsIter: w:negative,
# locs:[('55_000.bin', 2442)]
# PostingLocsIter: w:trying,
# locs:[('55_000.bin', 3180)]
# PostingLocsIter: w:international,
# locs:[('55_000.bin', 3744)]
# PostingLocsIter: w:american,
# locs:[('55_000.bin', 5988)]
# PostingLocsIter: w:positive,
# locs:[('55_000.bin', 8778)]
# PostingLocsIter: w:possible,
# locs:[('55_000.bin', 9522)]
# PostingLocsIter: w:necessary,
# locs:[('55_000.bin', 11598)]
# PostingLocsIter: w:overall,
# locs:[('55_000.bin', 12744)]
# PostingLocsIter: w:focuses,
# locs:[('55_000.bin', 13692)]
# PostingLocsIter: w:survival,
# locs:[('55_000.bin', 14028)]
# PostingLocsIter: w:reduce,
# locs:[('55_000.bin', 14388)]
# PostingLocsIter: w:assist,
# locs:[('55_000.bin', 15102)]
# PostingLocsIter: w:superior,
# locs:[('55_000.bin', 15510)]
# PostingLocsIter: w:intellectual,
# locs:[('55_000.bin', 16062)]
# PostingLocsIter: w:exposure,
# locs:[('55_000.bin', 16584)]
# PostingLocsIter: w:hours,
# locs:[('55_000.bin', 17034)]
# PostingLocsIter: w:currently,
# locs:[('55_000.bin', 17994)]
# PostingLocsIter: w:striking,
# locs:[('55_000.bin', 19116)]
# PostingLocsIter: w:almost,
# locs:[('55_000.bin', 19434)]
# PostingLocsIter: w:present-day,
# locs:[('55_000.bin', 21672)]
# PostingLocsIter: w:politically,
# locs:[('55_000.bin', 22212)]
# PostingLocsIter: w:passage,
# locs:[('55_000.bin', 22524)]
# PostingLocsIter: w:burned,
# locs:[('55_000.bin', 23070)]
# PostingLocsIter: w:numbers,
# locs:[('55_000.bin', 23454)]
# PostingLocsIter: w:1937,
# locs:[('55_000.bin', 24810)]
# PostingLocsIter: w:specifically,
# locs:[('55_000.bin', 25608)]
# PostingLocsIter: w:assembly,
# locs:[('55_000.bin', 26718)]
# PostingLocsIter: w:companies,
# locs:[('55_000.bin', 27486)]
# PostingLocsIter: w:achievement,
# locs:[('55_000.bin', 28266)]
# PostingLocsIter: w:vast,
# locs:[('55_000.bin', 28602)]
# PostingLocsIter: w:married,
# locs:[('55_000.bin', 29352)]
# PostingLocsIter: w:125,
# locs:[('55_000.bin', 30582)]
# PostingLocsIter: w:guy,
# locs:[('55_000.bin', 30930)]
# PostingLocsIter: w:murdered,
# locs:[('55_000.bin', 31254)]
# PostingLocsIter: w:scholarship,
# locs:[('55_000.bin', 31704)]
# PostingLocsIter: w:fundamental,
# locs:[('55_000.bin', 32022)]
# PostingLocsIter: w:liquid,
# locs:[('55_000.bin', 32610)]
# PostingLocsIter: w:com,
# locs:[('55_000.bin', 32964)]
# PostingLocsIter: w:hungary,
# locs:[('55_000.bin', 33492)]
# PostingLocsIter: w:meaning,
# locs:[('35_000.bin', 0)]
# PostingLocsIter: w:french,
# locs:[('35_000.bin', 1806)]
# PostingLocsIter: w:joined,
# locs:[('35_000.bin', 4002)]
# PostingLocsIter: w:black,
# locs:[('35_000.bin', 5232)]
# PostingLocsIter: w:distinct,
# locs:[('35_000.bin', 6984)]
# PostingLocsIter: w:strike,
# locs:[('35_000.bin', 8022)]
# PostingLocsIter: w:contrast,
# locs:[('35_000.bin', 8382)]
# PostingLocsIter: w:artist,
# locs:[('35_000.bin', 9522)]
# PostingLocsIter: w:19th-century,
# locs:[('35_000.bin', 10326)]
# PostingLocsIter: w:functions,
# locs:[('35_000.bin', 10824)]
# PostingLocsIter: w:severe,
# locs:[('35_000.bin', 11694)]
# PostingLocsIter: w:models,
# locs:[('35_000.bin', 12396)]
# PostingLocsIter: w:health,
# locs:[('35_000.bin', 13008)]
# PostingLocsIter: w:standard,
# locs:[('35_000.bin', 14184)]
# PostingLocsIter: w:ireland,
# locs:[('35_000.bin', 15666)]
# PostingLocsIter: w:someone,
# locs:[('35_000.bin', 16410)]
# PostingLocsIter: w:african,
# locs:[('35_000.bin', 16926)]
# PostingLocsIter: w:agriculture,
# locs:[('35_000.bin', 17976)]
# PostingLocsIter: w:stephen,
# locs:[('35_000.bin', 18450)]
# PostingLocsIter: w:1913,
# locs:[('35_000.bin', 19224)]
# PostingLocsIter: w:edge,
# locs:[('35_000.bin', 19944)]
# PostingLocsIter: w:nine,
# locs:[('35_000.bin', 20460)]
# PostingLocsIter: w:invention,
# locs:[('35_000.bin', 21522)]
# PostingLocsIter: w:drama,
# locs:[('35_000.bin', 21948)]
# PostingLocsIter: w:chain,
# locs:[('35_000.bin', 22302)]
# PostingLocsIter: w:1935,
# locs:[('35_000.bin', 22878)]
# PostingLocsIter: w:1949,
# locs:[('35_000.bin', 23562)]
# PostingLocsIter: w:kill,
# locs:[('35_000.bin', 24360)]
# PostingLocsIter: w:weak,
# locs:[('35_000.bin', 24912)]
# PostingLocsIter: w:canadian,
# locs:[('35_000.bin', 25488)]
# PostingLocsIter: w:collaboration,
# locs:[('35_000.bin', 26334)]
# PostingLocsIter: w:dated,
# locs:[('35_000.bin', 26682)]
# PostingLocsIter: w:theologian,
# locs:[('35_000.bin', 27312)]
# PostingLocsIter: w:hungarian,
# locs:[('35_000.bin', 27750)]
# PostingLocsIter: w:driver,
# locs:[('35_000.bin', 28230)]
# PostingLocsIter: w:photographer,
# locs:[('35_000.bin', 28746)]
# PostingLocsIter: w:ruler,
# locs:[('90_000.bin', 0)]
# PostingLocsIter: w:carl,
# locs:[('90_000.bin', 570)]
# PostingLocsIter: w:tradition,
# locs:[('90_000.bin', 1188)]
# PostingLocsIter: w:found,
# locs:[('90_000.bin', 2376)]
# PostingLocsIter: w:led,
# locs:[('90_000.bin', 5604)]
# PostingLocsIter: w:together,
# locs:[('90_000.bin', 8262)]
# PostingLocsIter: w:enemies,
# locs:[('90_000.bin', 10398)]
# PostingLocsIter: w:book,
# locs:[('90_000.bin', 10836)]
# PostingLocsIter: w:otherwise,
# locs:[('90_000.bin', 12948)]
# PostingLocsIter: w:intended,
# locs:[('90_000.bin', 13920)]
# PostingLocsIter: w:replaced,
# locs:[('90_000.bin', 15156)]
# PostingLocsIter: w:regard,
# locs:[('90_000.bin', 16626)]
# PostingLocsIter: w:geographic,
# locs:[('90_000.bin', 17130)]
# PostingLocsIter: w:burning,
# locs:[('90_000.bin', 17508)]
# PostingLocsIter: w:required,
# locs:[('90_000.bin', 17910)]
# PostingLocsIter: w:formation,
# locs:[('90_000.bin', 19554)]
# PostingLocsIter: w:shorter,
# locs:[('90_000.bin', 20508)]
# PostingLocsIter: w:voted,
# locs:[('90_000.bin', 20922)]
# PostingLocsIter: w:ones,
# locs:[('90_000.bin', 21372)]
# PostingLocsIter: w:census,
# locs:[('90_000.bin', 22242)]
# PostingLocsIter: w:statue,
# locs:[('90_000.bin', 22566)]
# PostingLocsIter: w:recorded,
# locs:[('90_000.bin', 23196)]
# PostingLocsIter: w:500,
# locs:[('90_000.bin', 24378)]
# PostingLocsIter: w:institution,
# locs:[('90_000.bin', 25686)]
# PostingLocsIter: w:club,
# locs:[('90_000.bin', 26268)]
# PostingLocsIter: w:tour,
# locs:[('90_000.bin', 27000)]
# PostingLocsIter: w:saved,
# locs:[('90_000.bin', 27462)]
# PostingLocsIter: w:1976,
# locs:[('90_000.bin', 27804)]
# PostingLocsIter: w:carlos,
# locs:[('90_000.bin', 28878)]
# PostingLocsIter: w:publication,
# locs:[('90_000.bin', 29226)]
# PostingLocsIter: w:opinion,
# locs:[('90_000.bin', 29976)]
# PostingLocsIter: w:people's,
# locs:[('90_000.bin', 30540)]
# PostingLocsIter: w:tony,
# locs:[('90_000.bin', 31086)]
# PostingLocsIter: w:julian,
# locs:[('90_000.bin', 31476)]
# PostingLocsIter: w:extends,
# locs:[('90_000.bin', 31854)]
# PostingLocsIter: w:word,
# locs:[('3_000.bin', 0)]
# PostingLocsIter: w:government,
# locs:[('3_000.bin', 1722)]
# PostingLocsIter: w:tendency,
# locs:[('3_000.bin', 3600)]
# PostingLocsIter: w:accept,
# locs:[('3_000.bin', 3930)]
# PostingLocsIter: w:increasingly,
# locs:[('3_000.bin', 4584)]
# PostingLocsIter: w:reverse,
# locs:[('3_000.bin', 5412)]
# PostingLocsIter: w:lines,
# locs:[('3_000.bin', 5838)]
# PostingLocsIter: w:global,
# locs:[('3_000.bin', 7176)]
# PostingLocsIter: w:refers,
# locs:[('3_000.bin', 7980)]
# PostingLocsIter: w:introduced,
# locs:[('3_000.bin', 9132)]
# PostingLocsIter: w:unit,
# locs:[('3_000.bin', 10842)]
# PostingLocsIter: w:scientists,
# locs:[('3_000.bin', 11802)]
# PostingLocsIter: w:valley,
# locs:[('3_000.bin', 12540)]
# PostingLocsIter: w:manufacturing,
# locs:[('3_000.bin', 13248)]
# PostingLocsIter: w:yellow,
# locs:[('3_000.bin', 13794)]
# PostingLocsIter: w:continues,
# locs:[('3_000.bin', 14304)]
# PostingLocsIter: w:interpreted,
# locs:[('3_000.bin', 15054)]
# PostingLocsIter: w:tomb,
# locs:[('3_000.bin', 15588)]
# PostingLocsIter: w:1885,
# locs:[('3_000.bin', 16026)]
# PostingLocsIter: w:owned,
# locs:[('3_000.bin', 16488)]
# PostingLocsIter: w:1853,
# locs:[('3_000.bin', 17118)]
# PostingLocsIter: w:germany,
# locs:[('3_000.bin', 17436)]
# PostingLocsIter: w:teacher,
# locs:[('3_000.bin', 18888)]
# PostingLocsIter: w:element,
# locs:[('3_000.bin', 19410)]
# PostingLocsIter: w:altered,
# locs:[('3_000.bin', 20166)]
# PostingLocsIter: w:faculty,
# locs:[('3_000.bin', 20478)]
# PostingLocsIter: w:alexandria,
# locs:[('3_000.bin', 20796)]
# PostingLocsIter: w:pianist,
# locs:[('3_000.bin', 21174)]
# PostingLocsIter: w:equipment,
# locs:[('3_000.bin', 21570)]
# PostingLocsIter: w:uncertain,
# locs:[('3_000.bin', 22248)]
# PostingLocsIter: w:leader,
# locs:[('70_000.bin', 0)]
# PostingLocsIter: w:power,
# locs:[('70_000.bin', 1296)]
# PostingLocsIter: w:study,
# locs:[('70_000.bin', 3552)]
# PostingLocsIter: w:1999,
# locs:[('70_000.bin', 5244)]
# PostingLocsIter: w:software,
# locs:[('70_000.bin', 6906)]
# PostingLocsIter: w:love,
# locs:[('70_000.bin', 7494)]
# PostingLocsIter: w:naturally,
# locs:[('70_000.bin', 8418)]
# PostingLocsIter: w:appeal,
# locs:[('70_000.bin', 8856)]
# PostingLocsIter: w:genetic,
# locs:[('70_000.bin', 9354)]
# PostingLocsIter: w:2000,
# locs:[('70_000.bin', 9702)]
# PostingLocsIter: w:repeatedly,
# locs:[('70_000.bin', 11484)]
# PostingLocsIter: w:ranging,
# locs:[('70_000.bin', 11880)]
# PostingLocsIter: w:unclear,
# locs:[('70_000.bin', 12396)]
# PostingLocsIter: w:points,
# locs:[('70_000.bin', 12780)]
# PostingLocsIter: w:grow,
# locs:[('70_000.bin', 13986)]
# PostingLocsIter: w:estimate,
# locs:[('70_000.bin', 14526)]
# PostingLocsIter: w:story,
# locs:[('70_000.bin', 14856)]
# PostingLocsIter: w:surfaces,
# locs:[('70_000.bin', 16284)]
# PostingLocsIter: w:dark,
# locs:[('70_000.bin', 16632)]
# PostingLocsIter: w:least,
# locs:[('70_000.bin', 17382)]
# PostingLocsIter: w:arabic,
# locs:[('70_000.bin', 19722)]
# PostingLocsIter: w:officers,
# locs:[('70_000.bin', 20196)]
# PostingLocsIter: w:establishments,
# locs:[('70_000.bin', 20736)]
# PostingLocsIter: w:destroyed,
# locs:[('70_000.bin', 21240)]
# PostingLocsIter: w:adaptation,
# locs:[('70_000.bin', 22092)]
# PostingLocsIter: w:noting,
# locs:[('70_000.bin', 22434)]
# PostingLocsIter: w:julius,
# locs:[('70_000.bin', 22776)]
# PostingLocsIter: w:giant,
# locs:[('70_000.bin', 23232)]
# PostingLocsIter: w:controversy,
# locs:[('70_000.bin', 23634)]
# PostingLocsIter: w:bishop,
# locs:[('70_000.bin', 24126)]
# PostingLocsIter: w:massacre,
# locs:[('70_000.bin', 24882)]
# PostingLocsIter: w:pilot,
# locs:[('70_000.bin', 25260)]
# PostingLocsIter: w:cable,
# locs:[('70_000.bin', 25854)]
# PostingLocsIter: w:current,
# locs:[('22_000.bin', 0)]
# PostingLocsIter: w:rather,
# locs:[('22_000.bin', 1542)]
# PostingLocsIter: w:conflicts,
# locs:[('22_000.bin', 3816)]
# PostingLocsIter: w:influences,
# locs:[('22_000.bin', 4272)]
# PostingLocsIter: w:occurs,
# locs:[('22_000.bin', 4794)]
# PostingLocsIter: w:learn,
# locs:[('22_000.bin', 5694)]
# PostingLocsIter: w:face,
# locs:[('22_000.bin', 6252)]
# PostingLocsIter: w:2016,
# locs:[('22_000.bin', 7188)]
# PostingLocsIter: w:depend,
# locs:[('22_000.bin', 8646)]
# PostingLocsIter: w:widespread,
# locs:[('22_000.bin', 8958)]
# PostingLocsIter: w:victor,
# locs:[('22_000.bin', 9750)]
# PostingLocsIter: w:temperatures,
# locs:[('22_000.bin', 10128)]
# PostingLocsIter: w:leads,
# locs:[('22_000.bin', 10572)]
# PostingLocsIter: w:town,
# locs:[('22_000.bin', 11274)]
# PostingLocsIter: w:billion,
# locs:[('22_000.bin', 12564)]
# PostingLocsIter: w:get,
# locs:[('22_000.bin', 13194)]
# PostingLocsIter: w:policy,
# locs:[('22_000.bin', 14292)]
# PostingLocsIter: w:elections,
# locs:[('22_000.bin', 15072)]
# PostingLocsIter: w:speak,
# locs:[('22_000.bin', 15450)]
# PostingLocsIter: w:gallery,
# locs:[('22_000.bin', 16056)]
# PostingLocsIter: w:murder,
# locs:[('22_000.bin', 16602)]
# PostingLocsIter: w:suspected,
# locs:[('22_000.bin', 17190)]
# PostingLocsIter: w:consequences,
# locs:[('22_000.bin', 17562)]
# PostingLocsIter: w:stars,
# locs:[('22_000.bin', 17988)]
# PostingLocsIter: w:seriously,
# locs:[('22_000.bin', 18516)]
# PostingLocsIter: w:bernard,
# locs:[('22_000.bin', 18864)]
# PostingLocsIter: w:honor,
# locs:[('22_000.bin', 19302)]
# PostingLocsIter: w:ben,
# locs:[('22_000.bin', 20016)]
# PostingLocsIter: w:save,
# locs:[('22_000.bin', 20436)]
# PostingLocsIter: w:appears,
# locs:[('24_000.bin', 0)]
# PostingLocsIter: w:including,
# locs:[('24_000.bin', 1458)]
# PostingLocsIter: w:hard,
# locs:[('24_000.bin', 5214)]
# PostingLocsIter: w:thinking,
# locs:[('24_000.bin', 6186)]
# PostingLocsIter: w:different,
# locs:[('24_000.bin', 6612)]
# PostingLocsIter: w:fixed,
# locs:[('24_000.bin', 9498)]
# PostingLocsIter: w:fields,
# locs:[('24_000.bin', 10122)]
# PostingLocsIter: w:issues,
# locs:[('24_000.bin', 10974)]
# PostingLocsIter: w:restricted,
# locs:[('24_000.bin', 12096)]
# PostingLocsIter: w:natural,
# locs:[('24_000.bin', 12648)]
# PostingLocsIter: w:longer,
# locs:[('24_000.bin', 14340)]
# PostingLocsIter: w:bar,
# locs:[('24_000.bin', 15822)]
# PostingLocsIter: w:paper,
# locs:[('24_000.bin', 16248)]
# PostingLocsIter: w:value,
# locs:[('24_000.bin', 17178)]
# PostingLocsIter: w:wealth,
# locs:[('24_000.bin', 18282)]
# PostingLocsIter: w:hit,
# locs:[('24_000.bin', 18780)]
# PostingLocsIter: w:restore,
# locs:[('24_000.bin', 19404)]
# PostingLocsIter: w:subjects,
# locs:[('24_000.bin', 19716)]
# PostingLocsIter: w:francis,
# locs:[('24_000.bin', 20304)]
# PostingLocsIter: w:nuclear,
# locs:[('24_000.bin', 20952)]
# PostingLocsIter: w:early,
# locs:[('58_000.bin', 0)]
# PostingLocsIter: w:soil,
# locs:[('58_000.bin', 3774)]
# PostingLocsIter: w:free,
# locs:[('58_000.bin', 4212)]
# PostingLocsIter: w:democratic,
# locs:[('58_000.bin', 5916)]
# PostingLocsIter: w:emphasis,
# locs:[('58_000.bin', 6468)]
# PostingLocsIter: w:people,
# locs:[('58_000.bin', 7014)]
# PostingLocsIter: w:regardless,
# locs:[('58_000.bin', 10692)]
# PostingLocsIter: w:novel,
# ...
# locs:[('98_000.bin', 4356)]
# PostingLocsIter: w:present,
# locs:[('98_000.bin', 5202)]
# PostingLocsIter: w:evidence,
# locs:[('98_000.bin', 7506)]
# PostingLocsIter: w:given,
# locs:[('98_000.bin', 9114)]
# PostingLocsIter: w:wild,
# locs:[('98_000.bin', 11964)]
# PostingLocsIter: w:fresh,
# locs:[('98_000.bin', 12426)]
# PostingLocsIter: w:opposite,
# locs:[('98_000.bin', 12840)]
# PostingLocsIter: w:1900,
# locs:[('98_000.bin', 13500)]
# PostingLocsIter: w:1941,
# locs:[('98_000.bin', 14340)]
# PostingLocsIter: w:donated,
# locs:[('98_000.bin', 15156)]
# PostingLocsIter: w:installed,
# locs:[('98_000.bin', 15468)]
# PostingLocsIter: w:1990,
# locs:[('98_000.bin', 15942)]
# PostingLocsIter: w:shield,
# locs:[('98_000.bin', 17298)]
# PostingLocsIter: w:designated,
# locs:[('98_000.bin', 17658)]
# PostingLocsIter: w:earlier,
# locs:[('98_000.bin', 18210)]
# PostingLocsIter: w:ships,
# locs:[('98_000.bin', 19956)]
# PostingLocsIter: w:commander,
# locs:[('98_000.bin', 20616)]
# PostingLocsIter: w:motion,
# locs:[('98_000.bin', 21384)]
# PostingLocsIter: w:railway,
# locs:[('98_000.bin', 22026)]
# PostingLocsIter: w:ottoman,
# locs:[('98_000.bin', 22506)]
# PostingLocsIter: w:iii,
# locs:[('98_000.bin', 22932)]
# PostingLocsIter: w:teach,
# locs:[('98_000.bin', 24474)]
# PostingLocsIter: w:deals,
# locs:[('98_000.bin', 24780)]
# PostingLocsIter: w:amateur,
# locs:[('98_000.bin', 25104)]
# PostingLocsIter: w:streets,
# locs:[('98_000.bin', 25422)]
# PostingLocsIter: w:predicted,
# locs:[('92_000.bin', 0)]
# PostingLocsIter: w:beyond,
# locs:[('92_000.bin', 384)]
# PostingLocsIter: w:works,
# locs:[('92_000.bin', 1638)]
# PostingLocsIter: w:easier,
# locs:[('92_000.bin', 3624)]
# PostingLocsIter: w:russell,
# locs:[('92_000.bin', 4116)]
# PostingLocsIter: w:resolved,
# locs:[('92_000.bin', 4530)]
# PostingLocsIter: w:deeply,
# locs:[('92_000.bin', 4914)]
# PostingLocsIter: w:variants,
# locs:[('92_000.bin', 5424)]
# PostingLocsIter: w:gene,
# locs:[('92_000.bin', 5814)]
# PostingLocsIter: w:corresponding,
# locs:[('92_000.bin', 6150)]
# PostingLocsIter: w:2004,
# locs:[('92_000.bin', 6822)]
# PostingLocsIter: w:manner,
# locs:[('92_000.bin', 8430)]
# PostingLocsIter: w:medium,
# locs:[('92_000.bin', 9144)]
# PostingLocsIter: w:tribes,
# locs:[('92_000.bin', 9612)]
# PostingLocsIter: w:centers,
# locs:[('92_000.bin', 10062)]
# PostingLocsIter: w:statistics,
# locs:[('92_000.bin', 10530)]
# PostingLocsIter: w:metropolitan,
# locs:[('92_000.bin', 11040)]
# PostingLocsIter: w:arm,
# locs:[('92_000.bin', 11466)]
# PostingLocsIter: w:covers,
# locs:[('92_000.bin', 11940)]
# PostingLocsIter: w:buried,
# locs:[('92_000.bin', 12420)]
# PostingLocsIter: w:geographical,
# locs:[('92_000.bin', 13242)]
# PostingLocsIter: w:citizen,
# locs:[('92_000.bin', 13548)]
# PostingLocsIter: w:assembled,
# locs:[('92_000.bin', 13872)]
# PostingLocsIter: w:bought,
# locs:[('92_000.bin', 14262)]
# PostingLocsIter: w:ensure,
# locs:[('92_000.bin', 14718)]
# PostingLocsIter: w:absence,
# locs:[('92_000.bin', 15222)]
# PostingLocsIter: w:documents,
# locs:[('92_000.bin', 15930)]
# PostingLocsIter: w:resource,
# locs:[('92_000.bin', 16608)]
# PostingLocsIter: w:interpretation,
# locs:[('92_000.bin', 16950)]
# PostingLocsIter: w:step,
# locs:[('92_000.bin', 17502)]
# PostingLocsIter: w:horses,
# locs:[('92_000.bin', 18138)]
# PostingLocsIter: w:biggest,
# locs:[('92_000.bin', 18498)]
# PostingLocsIter: w:owner,
# locs:[('92_000.bin', 18906)]
# PostingLocsIter: w:converted,
# locs:[('92_000.bin', 19326)]
# PostingLocsIter: w:string,
# locs:[('92_000.bin', 20052)]
# PostingLocsIter: w:1873,
# locs:[('92_000.bin', 20370)]
# PostingLocsIter: w:colonel,
# locs:[('92_000.bin', 20790)]
# PostingLocsIter: w:drew,
# locs:[('42_000.bin', 0)]
# PostingLocsIter: w:inspiration,
# locs:[('42_000.bin', 492)]
# PostingLocsIter: w:green,
# locs:[('42_000.bin', 858)]
# PostingLocsIter: w:widely,
# locs:[('42_000.bin', 1944)]
# PostingLocsIter: w:aims,
# locs:[('42_000.bin', 3624)]
# PostingLocsIter: w:identical,
# locs:[('42_000.bin', 3936)]
# PostingLocsIter: w:north,
# locs:[('42_000.bin', 4506)]
# PostingLocsIter: w:six,
# locs:[('42_000.bin', 6810)]
# PostingLocsIter: w:year,
# locs:[('42_000.bin', 8568)]
# PostingLocsIter: w:aged,
# locs:[('42_000.bin', 11832)]
# PostingLocsIter: w:male,
# locs:[('42_000.bin', 12306)]
# PostingLocsIter: w:previously,
# locs:[('42_000.bin', 13506)]
# PostingLocsIter: w:weeks,
# locs:[('42_000.bin', 14904)]
# PostingLocsIter: w:instrument,
# locs:[('42_000.bin', 15636)]
# PostingLocsIter: w:mark,
# locs:[('42_000.bin', 16020)]
# PostingLocsIter: w:county,
# locs:[('42_000.bin', 17274)]
# PostingLocsIter: w:pay,
# locs:[('42_000.bin', 18066)]
# PostingLocsIter: w:goddess,
# locs:[('42_000.bin', 18762)]
# PostingLocsIter: w:girl,
# locs:[('42_000.bin', 19110)]
# PostingLocsIter: w:custom,
# locs:[('42_000.bin', 19440)]
# PostingLocsIter: w:leaves,
# locs:[('42_000.bin', 19776)]
# PostingLocsIter: w:titled,
# locs:[('42_000.bin', 20340)]
# PostingLocsIter: w:expand,
# locs:[('42_000.bin', 20892)]
# PostingLocsIter: w:newspaper,
# locs:[('42_000.bin', 21276)]
# PostingLocsIter: w:prevented,
# locs:[('42_000.bin', 21822)]
# PostingLocsIter: w:choice,
# locs:[('42_000.bin', 22170)]
# PostingLocsIter: w:sculptor,
# locs:[('42_000.bin', 23004)]
# PostingLocsIter: w:stored,
# locs:[('42_000.bin', 23508)]
# PostingLocsIter: w:excess,
# locs:[('42_000.bin', 23934)]
# PostingLocsIter: w:scholar,
# locs:[('42_000.bin', 24264)]
# PostingLocsIter: w:succession,
# locs:[('42_000.bin', 25110)]
# PostingLocsIter: w:exile,
# locs:[('97_000.bin', 0)]
# PostingLocsIter: w:spain,
# locs:[('97_000.bin', 378)]
# PostingLocsIter: w:existence,
# locs:[('97_000.bin', 1356)]
# PostingLocsIter: w:legitimate,
# locs:[('97_000.bin', 2256)]
# PostingLocsIter: w:pair,
# locs:[('97_000.bin', 2568)]
# PostingLocsIter: w:pairs,
# locs:[('97_000.bin', 3150)]
# PostingLocsIter: w:near,
# locs:[('97_000.bin', 3504)]
# PostingLocsIter: w:1972,
# locs:[('97_000.bin', 6012)]
# PostingLocsIter: w:spend,
# locs:[('97_000.bin', 7110)]
# PostingLocsIter: w:territories,
# locs:[('97_000.bin', 7482)]
# PostingLocsIter: w:heroes,
# locs:[('97_000.bin', 8100)]
# PostingLocsIter: w:inscription,
# locs:[('97_000.bin', 8442)]
# PostingLocsIter: w:princess,
# locs:[('97_000.bin', 8826)]
# PostingLocsIter: w:lying,
# locs:[('97_000.bin', 9324)]
# PostingLocsIter: w:novels,
# locs:[('97_000.bin', 9666)]
# PostingLocsIter: w:secure,
# locs:[('97_000.bin', 9996)]
# PostingLocsIter: w:seemed,
# locs:[('97_000.bin', 10488)]
# PostingLocsIter: w:defense,
# locs:[('97_000.bin', 10890)]
# PostingLocsIter: w:looked,
# locs:[('97_000.bin', 11676)]
# PostingLocsIter: w:procedures,
# locs:[('97_000.bin', 12066)]
# PostingLocsIter: w:damaged,
# locs:[('97_000.bin', 12474)]
# PostingLocsIter: w:1912,
# locs:[('97_000.bin', 12924)]
# PostingLocsIter: w:manage,
# locs:[('97_000.bin', 13620)]
# PostingLocsIter: w:illustrator,
# locs:[('97_000.bin', 13944)]
# PostingLocsIter: w:philippines,
# locs:[('97_000.bin', 14292)]
# PostingLocsIter: w:sets,
# locs:[('103_000.bin', 0)]
# PostingLocsIter: w:vision,
# locs:[('103_000.bin', 672)]
# PostingLocsIter: w:suggesting,
# locs:[('103_000.bin', 1158)]
# PostingLocsIter: w:actual,
# locs:[('103_000.bin', 1596)]
# PostingLocsIter: w:combinations,
# locs:[('103_000.bin', 2460)]
# PostingLocsIter: w:conducted,
# locs:[('103_000.bin', 2778)]
# PostingLocsIter: w:applications,
# locs:[('103_000.bin', 3612)]
# PostingLocsIter: w:neutral,
# locs:[('103_000.bin', 4332)]
# PostingLocsIter: w:medieval,
# locs:[('103_000.bin', 4704)]
# PostingLocsIter: w:status,
# locs:[('103_000.bin', 5544)]
# PostingLocsIter: w:house,
# locs:[('103_000.bin', 6726)]
# PostingLocsIter: w:species,
# locs:[('103_000.bin', 8646)]
# PostingLocsIter: w:density,
# locs:[('103_000.bin', 9462)]
# PostingLocsIter: w:100,
# locs:[('103_000.bin', 9870)]
# PostingLocsIter: w:expansion,
# locs:[('103_000.bin', 11652)]
# PostingLocsIter: w:1973,
# locs:[('103_000.bin', 12426)]
# PostingLocsIter: w:excluding,
# locs:[('103_000.bin', 13482)]
# PostingLocsIter: w:outstanding,
# locs:[('103_000.bin', 13830)]
# PostingLocsIter: w:founder,
# locs:[('103_000.bin', 14172)]
# PostingLocsIter: w:format,
# locs:[('103_000.bin', 15132)]
# PostingLocsIter: w:nevertheless,
# locs:[('103_000.bin', 15576)]
# PostingLocsIter: w:correspondence,
# locs:[('103_000.bin', 16386)]
# PostingLocsIter: w:artists,
# locs:[('45_000.bin', 0)]
# PostingLocsIter: w:forming,
# locs:[('45_000.bin', 600)]
# PostingLocsIter: w:release,
# locs:[('45_000.bin', 1260)]
# PostingLocsIter: w:cooperation,
# locs:[('45_000.bin', 2184)]
# PostingLocsIter: w:identify,
# locs:[('45_000.bin', 2532)]
# PostingLocsIter: w:allowing,
# locs:[('45_000.bin', 3198)]
# PostingLocsIter: w:documented,
# locs:[('45_000.bin', 4296)]
# PostingLocsIter: w:compiled,
# locs:[('45_000.bin', 4704)]
# PostingLocsIter: w:mathematical,
# locs:[('45_000.bin', 5010)]
# PostingLocsIter: w:original,
# locs:[('45_000.bin', 5472)]
# PostingLocsIter: w:projects,
# locs:[('45_000.bin', 7602)]
# PostingLocsIter: w:appearance,
# locs:[('45_000.bin', 8232)]
# PostingLocsIter: w:tourism,
# locs:[('45_000.bin', 9234)]
# PostingLocsIter: w:biblical,
# locs:[('45_000.bin', 9558)]
# PostingLocsIter: w:train,
# locs:[('45_000.bin', 9972)]
# PostingLocsIter: w:secret,
# locs:[('45_000.bin', 10656)]
# PostingLocsIter: w:bce,
# locs:[('45_000.bin', 11370)]
# PostingLocsIter: w:carries,
# locs:[('45_000.bin', 11694)]
# PostingLocsIter: w:boston,
# locs:[('45_000.bin', 12048)]
# PostingLocsIter: w:albert,
# locs:[('45_000.bin', 12528)]
# PostingLocsIter: w:michigan,
# locs:[('45_000.bin', 13362)]
# PostingLocsIter: w:delivered,
# locs:[('45_000.bin', 13770)]
# PostingLocsIter: w:soul,
# locs:[('45_000.bin', 14334)]
# PostingLocsIter: w:bottom,
# locs:[('45_000.bin', 14802)]
# PostingLocsIter: w:chosen,
# locs:[('45_000.bin', 15354)]
# PostingLocsIter: w:dramatic,
# locs:[('45_000.bin', 16308)]
# PostingLocsIter: w:scheduled,
# locs:[('45_000.bin', 16782)]
# PostingLocsIter: w:fred,
# locs:[('45_000.bin', 17094)]
# PostingLocsIter: w:arrival,
# locs:[('45_000.bin', 17448)]
# PostingLocsIter: w:1917,
# locs:[('45_000.bin', 18048)]
# PostingLocsIter: w:depicting,
# locs:[('45_000.bin', 18708)]
# PostingLocsIter: w:facing,
# locs:[('45_000.bin', 19122)]
# PostingLocsIter: w:korea,
# locs:[('45_000.bin', 19500)]
# PostingLocsIter: w:virgin,
# locs:[('45_000.bin', 19914)]
# Query: ['first', 'test']
# words:('political', 'history', 'toward', '1903', 'technologies', 'ability', 'serve', '2008', 'urban', 'traced', 'estimates', '1980', 'sea', 'americans', 'institute', 'computer', 'horse', 'willing', 'anthony', 'simon', 'viii', 'instrumental', 'channel', 'achievements', 'louis', 'variety', 'christopher', 'stronger', 'convert', 'obvious', 'substantially', 'astronaut', 'philosophy', 'next', 'differently', 'times', 'could', 'criticized', 'principal', 'combination', 'hypothesis', 'tools', 'depression', 'categories', 'portrait', 'depends', 'old', 'seats', 'walls', 'protestant', 'terminal', 'apollo', 'lacked', 'intent', 'appearing', 'screenwriter', 'programme', 'racing', 'françois', 'movement', 'ancient', 'create', 'authors', 'islam', 'friendship', 'responsible', 'developing', 'complex', 'roles', 'child', 'publications', 'argue', 'function', 'testing', 'case', 'gas', 'civilization', '1860', '600', '2011', 'grounds', 'yield', 'send', 'seized', 'exactly', 'sending', 'critic', '1989', 'comic', 'limits', 'portugal', 'passes', 'borders', 'authority', 'civil', 'past', 'syria', 'paid', 'style', 'broad', 'college', 'related', 'loss', 'opportunities', 'reasons', 'regarded', '800', 'tree', 'held', '1954', 'command', 'operates', 'immediately', 'station', 'prince', 'prove', 'crisis', 'agreed', 'taylor', 'device', 'resigned', '1953', '1947', 'assisted', 'ltd', 'cape', 'forms', 'authorities', 'second', 'gained', 'types', 'multiple', 'broader', 'school', 'exhibit', 'consists', '4th', '5th', 'finally', 'computing', 'washington', 'operations', 'fishing', 'traces', 'rome', 'attack', 'boat', 'choose', 'meanwhile', 'armies', 'want', 'broken', 'bibliography', '1971', 'fashion', 'calls', 'back', 'formal', 'diverse', 'describe', 'really', 'general', 'extension', 'modern', 'golden', 'needs', 'legal', 'unity', 'divine', 'viewed', 'energy', 'continental', 'determining', 'island', 'join', 'something', 'coastal', '1874', 'anyone', 'polish', 'theater', 'cambridge', 'anna', 'gate', 'state', 'pursue', 'religious', 'seeing', 'commonly', 'bank', 'controversial', 'included', 'felt', 'line', 'whether', 'statistical', 'activities', 'forward', 'account', 'percentage', 'traditional', 'mercury', 'southern', 'military', 'northeast', 'rank', 'budget', 'sports', 'baseball', 'possibly', 'heard', 'maria', 'monk', 'austrian', 'holds', 'beliefs', 'executed', 'took', 'economic', 'evolution', 'kinds', 'data', 'controlled', 'deaths', 'job', '2005', 'occasionally', 'expressed', 'artificial', 'peoples', 'business', 'fourth', 'defeat', 'moves', 'requirement', 'computers', 'evolved', 'enjoyed', 'electricity', 'adopt', 'historically', 'merely', 'nonetheless', 'gain', 'action', 'every', 'les', 'rates', 'designed', 'side', 'hospital', 'changed', 'expedition', 'money', 'length', 'pass', 'retain', 'episode', 'gray', 'planned', 'moment', 'musical', '1946', 'prime', 'alternate', 'usually', 'last', 'stream', 'among', 'reaction', 'scientist', 'built', 'ranks', 'heads', 'living', 'acceptance', 'years', 'language', 'whereas', 'exists', 'upper', 'water', 'receive', 'campbell', 'confirmed', 'policies', 'mythology', 'gods', 'demonstrate', '1848', 'chairman', 'threat', 'assassinated', '1968', 'fame', 'shell', 'dialect', 'belgian', 'described', 'best', 'sought', 'control', 'organization', 'base', 'educational', 'artistic', 'effects', 'similarities', 'effectively', 'exposed', 'reach', 'permanent', 'farmers', '1965', 'populations', '1982', 'struck', 'selected', 'document', 'solid', 'fall', 'professional', 'roads', 'winning', 'arms', 'platform', 'adapted', 'fear', 'venice', '1927', 'parallel', 'topic', 'sir', 'alongside', 'include', 'new', 'member', 'take', 'active', 'coined', 'properties', 'enough', 'behavior', 'involving', 'across', 'material', 'processes', 'claim', 'benefits', 'adult', 'detail', 'relation', 'creating', 'eventually', 'invented', 'conservative', 'acquired', 'march', 'kept', 'office', 'chinese', '200', 'twenty', 'orange', 'clay', 'kings', '1899', 'austria', "mother's", 'reportedly', 'japa ...
# QueryToSearch  ['first', 'test']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-aa24febfcb6c> in <module>()
#     199     return jsonify(res)
#     200
# --> 201 search_body()
#
# <ipython-input-43-aa24febfcb6c> in search_body()
#      82     words, p_lst = get_posting_gen(index)
#      83     #nizan### changed from index to index 2
# ---> 84     doc_tfidf_mat = generate_document_tfidf_matrix(query, index, words, p_lst)
#      85     print(doc_tfidf_mat)
#      86     query_tfidf = generate_query_tfidf_vector(query, index)
#
# <ipython-input-41-db977e6320a6> in generate_document_tfidf_matrix(query_to_search, index, words, pls)
#      61     total_vocab_size = len(index.term_total)
#      62     candidates_scores = get_candidate_documents_and_scores(query_to_search, index, words,
# ---> 63                                                            pls)  # We do not need to utilize all document. Only the docuemnts which have corrspoinding terms with the query.
#      64     print(candidates_scores)
#      65     unique_candidates = np.unique([doc_id for doc_id, freq in candidates_scores.keys()])
#
# <ipython-input-41-db977e6320a6> in get_candidate_documents_and_scores(query_to_search, index, words, pls)
#     147             #nizan###changed str to int in doc
#     148             normlized_tfidf = [(doc_id, (freq / DL[int(doc_id)]) * math.log(N / index.df[term], 10)) for doc_id, freq in
# --> 149                                list_of_doc]
#     150
#     151             for doc_id, tfidf in normlized_tfidf:
#
# <ipython-input-41-db977e6320a6> in <listcomp>(.0)
#     146             list_of_doc = pls[words.index(term)]
#     147             #nizan###changed str to int in doc
# --> 148             normlized_tfidf = [(doc_id, (freq / DL[int(doc_id)]) * math.log(N / index.df[term], 10)) for doc_id, freq in
#     149                                list_of_doc]
#     150
#
# KeyError: 12

# %%
def tokenize(text, stopwords_set='english'):
    """
    This function aims in tokenize a text into a list of tokens. Moreover, it filter stopwords.

    Parameters:
    -----------
    text: string , represting the text to tokenize.
    stopwords: english for english stopwords, all to include corpus stopwords. default english

    Returns:
    -----------
    list of tokens (e.g., list of tokens).
    """
    assert stopwords_set == "all" or stopwords_set == "english"  # validate input for debugging

    # make stopwords set
    english_stopwords = frozenset(stopwords.words('english'))
    corpus_stopwords = ['category', 'references', 'also', 'links', 'extenal', 'see', 'thumb']
    stops = None
    if stopwords_set == "all":
        stops = english_stopwords.union(corpus_stopwords)
    elif stopwords_set == "english":
        stops = english_stopwords

    # tokenize
    RE_WORD = re.compile(r"""[\#\@\w](['\-]?\w){2,24}""", re.UNICODE)
    list_of_tokens = [token.group() for token in RE_WORD.finditer(text.lower()) if
                      token.group() not in stops]
    return list_of_tokens

def top_N_documents(df, N):
    """
    This function sort and filter the top N docuemnts (by score) for each query.

    Parameters
    ----------
    df: DataFrame (queries as rows, documents as columns)
    N: Integer (how many document to retrieve for each query)

    Returns:
    ----------
    top_N: dictionary is the following stracture:
          key - query id.
          value - sorted (according to score) list of pairs lengh of N. Eac pair within the list provide the following information (doc id, score)
    """
    # YOUR CODE HERE
    keys = list(df.T.columns)
    top_dict = dict()
    for key in keys:
        top_dict[key] = []
        for doc_id in range(len(df.columns)):
            top_dict[key].append((doc_id, df[doc_id][key]))
        top_dict[key].sort(key=lambda x: x[1], reverse=True)
        top_dict[key] = top_dict[key][:N]
    return top_dict

BLOCK_SIZE = 1999998


class MultiFileWriter:
    """ Sequential binary writer to multiple files of up to BLOCK_SIZE each. """

    def __init__(self, base_dir, name):
        self._base_dir = Path(base_dir)
        self._name = name
        self._file_gen = (open(self._base_dir / f'{name}_{i:03}.bin', 'wb')
                          for i in itertools.count())
        self._f = next(self._file_gen)

    def write(self, b):
        locs = []
        while len(b) > 0:
            pos = self._f.tell()
            remaining = BLOCK_SIZE - pos
            # if the current file is full, close and open a new one.
            if remaining == 0:
                self._f.close()
                self._f = next(self._file_gen)
                pos, remaining = 0, BLOCK_SIZE
            self._f.write(b[:remaining])
            locs.append((self._f.name, pos))
            b = b[remaining:]
        return locs

    def close(self):
        self._f.close()


class MultiFileReader:
    """ Sequential binary reader of multiple files of up to BLOCK_SIZE each. """

    def __init__(self):
        self._open_files = {}

    def read(self, locs, n_bytes):
        b = []
        for f_name, offset in locs:
            if f_name not in self._open_files:
                self._open_files[f_name] = open(f_name, 'rb')
            f = self._open_files[f_name]
            f.seek(offset)
            #nizan
            #n_read = min(n_bytes, BLOCK_SIZE - offset)
            #implement min function in myself
            if n_bytes < BLOCK_SIZE - offset:
              n_read = n_bytes
            else:
              n_read = BLOCK_SIZE - offset
            b.append(f.read(n_read))
            n_bytes -= n_read
        return b''.join(b)

    def close(self):
        for f in self._open_files.values():
            f.close()

    def __exit__(self, exc_type, exc_value, traceback):
        self.close()
        return False

TUPLE_SIZE = 6       # We're going to pack the doc_id and tf values in this 
                     # many bytes.
TF_MASK = 2 ** 16 - 1 # Masking the 16 low bits of an integer

DL = {}  # We're going to update and calculate this after each document. This will be usefull for the calculation of AVGDL (utilized in BM25) 
class InvertedIndex:  
  def __init__(self, docs={}):
    """ Initializes the inverted index and add documents to it (if provided).
    Parameters:
    -----------
      docs: dict mapping doc_id to list of tokens
    """
    # stores document frequency per term
    self.df = Counter()
    # stores total frequency per term
    self.term_total = Counter()
    # stores posting list per term while building the index (internally), 
    # otherwise too big to store in memory.
    self._posting_list = defaultdict(list)
    # mapping a term to posting file locations, which is a list of 
    # (file_name, offset) pairs. Since posting lists are big we are going to
    # write them to disk and just save their location in this list. We are 
    # using the MultiFileWriter helper class to write fixed-size files and store
    # for each term/posting list its list of locations. The offset represents 
    # the number of bytes from the beginning of the file where the posting list
    # starts. 
    self.posting_locs = defaultdict(list)
    
    for doc_id, tokens in docs.items():
      self.add_doc(doc_id, tokens)
  
  def posting_lists_iter(self):
    """ A generator that reads one posting list from disk and yields 
        a (word:str, [(doc_id:int, tf:int), ...]) tuple.
    """
    with closing(MultiFileReader()) as reader:
      for w, locs in self.posting_locs.items():
        #print(f"PostingLocsIter: w:{w}, \nlocs:{locs}")
        # read a certain number of bytes into variable b
        b = reader.read(locs, self.df[w] * TUPLE_SIZE)
        posting_list = []
        # convert the bytes read into `b` to a proper posting list.
        
        for i in range(self.df[w]):
          doc_id = int.from_bytes(b[i*TUPLE_SIZE:i*TUPLE_SIZE+4], 'big')
          tf = int.from_bytes(b[i*TUPLE_SIZE+4:(i+1)*TUPLE_SIZE], 'big')
          posting_list.append((doc_id, tf))
        
        yield w, posting_list

  def add_doc(self, doc_id, tokens):
    """ Adds a document to the index with a given `doc_id` and tokens. It counts
        the tf of tokens, then update the index (in memory, no storage 
        side-effects).
    """
    DL[(doc_id)] = DL.get(doc_id,0) + (len(tokens))
    w2cnt = Counter(tokens)
    self.term_total.update(w2cnt)
    
    #max_value = max(w2cnt.items(), key=operator.itemgetter(1))[1]
    # There was a bug with the above line - max was overwritten by something mysterious.
    # Its easier to rewrite it than find the bug, so here you go:
    max_value = 0
    max_tup = None
    for tup in w2cnt.items():
      if tup[1] > max_value:
        max_value = tup[1]
        max_tup = tup



    # frequencies = {key: value/max_value for key, value in frequencies.items()}
    for w, cnt in w2cnt.items():        
        self.df[w] = self.df.get(w, 0) + 1                
        self._posting_list[w].append((doc_id, cnt))


  def write(self, base_dir, name):
    """ Write the in-memory index to disk and populate the `posting_locs`
        variables with information about file location and offset of posting
        lists. Results in at least two files: 
        (1) posting files `name`XXX.bin containing the posting lists.
        (2) `name`.pkl containing the global term stats (e.g. df).
    """
    #### POSTINGS ####
    self.posting_locs = defaultdict(list)
    with closing(MultiFileWriter(base_dir, name)) as writer:
      # iterate over posting lists in lexicographic order
      for w in sorted(self._posting_list.keys()):
        self._write_a_posting_list(w, writer, sort=True)
    #### GLOBAL DICTIONARIES ####
    self._write_globals(base_dir, name)

  def _write_globals(self, base_dir, name):
    with open(Path(base_dir) / f'{name}.pkl', 'wb') as f:
      pickle.dump(self, f)

  def _write_a_posting_list(self, w, writer, sort=False):
    # sort the posting list by doc_id
    pl = self._posting_list[w]
    if sort:
      pl = sorted(pl, key=itemgetter(0))
    # convert to bytes    
    b = b''.join([(int(doc_id) << 16 | (tf & TF_MASK)).to_bytes(TUPLE_SIZE, 'big')
                  for doc_id, tf in pl])
    # write to file(s)
    locs = writer.write(b)
    # save file locations to index
    self.posting_locs[w].extend(locs) 

  def __getstate__(self):
    """ Modify how the object is pickled by removing the internal posting lists
        from the object's state dictionary. 
    """
    state = self.__dict__.copy()
    del state['_posting_list']
    return state

  @staticmethod
  def read_index(base_dir, name):
    with open(Path(base_dir) / f'{name}.pkl', 'rb') as f:
      return pickle.load(f)

  @staticmethod
  def delete_index(base_dir, name):
    path_globals = Path(base_dir) / f'{name}.pkl'
    path_globals.unlink()
    for p in Path(base_dir).rglob(f'{name}_*.bin'):
      p.unlink()
  


if __name__ == '__main__':
  pass
    # run the Flask RESTful API, make the server publicly available (host='0.0.0.0') on port 8080
    # app.run(host='0.0.0.0', port=8080, debug=True)

# %% [markdown]
# ## Old InvertedIndex. Use if new one doesnt work

# %%
TUPLE_SIZE = 6  # We're going to pack the doc_id and tf values in this
# many bytes.
TF_MASK = 2 ** 16 - 1  # Masking the 16 low bits of an integer


class InvertedIndex:
    def __init__(self, docs={}):
        """ Initializes the inverted index and add documents to it (if provided).
        Parameters:
        -----------
          docs: dict mapping doc_id to list of tokens
        """
        # stores document frequency per term
        self.df = Counter()
        # stores total frequency per term
        self.term_total = Counter()
        # stores posting list per term while building the index (internally),
        # otherwise too big to store in memory.
        self._posting_list = defaultdict(list)
        # mapping a term to posting file locations, which is a list of
        # (file_name, offset) pairs. Since posting lists are big we are going to
        # write them to disk and just save their location in this list. We are
        # using the MultiFileWriter helper class to write fixed-size files and store
        # for each term/posting list its list of locations. The offset represents
        # the number of bytes from the beginning of the file where the posting list
        # starts.
        self.posting_locs = defaultdict(list)

        for doc_id, tokens in docs.items():
            self.add_doc(doc_id, tokens)

    def add_doc(self, doc_id, tokens):
        """ Adds a document to the index with a given `doc_id` and tokens. It counts
            the tf of tokens, then update the index (in memory, no storage
            side-effects).
        """
        w2cnt = Counter(tokens)
        self.term_total.update(w2cnt)
        for w, cnt in w2cnt.items():
            self.df[w] = self.df.get(w, 0) + 1
            self._posting_list[w].append((doc_id, cnt))

    def write_index(self, base_dir, name):
        """ Write the in-memory index to disk. Results in the file:
            (1) `name`.pkl containing the global term stats (e.g. df).
        """
        self._write_globals(base_dir, name)

    def _write_globals(self, base_dir, name):
        with open(Path(base_dir) / f'{name}.pkl', 'wb') as f:
            pickle.dump(self, f)

    def __getstate__(self):
        """ Modify how the object is pickled by removing the internal posting lists
            from the object's state dictionary.
        """
        state = self.__dict__.copy()
        del state['_posting_list']
        return state

    def posting_lists_iter(self):
        """ A generator that reads one posting list from disk and yields
            a (word:str, [(doc_id:int, tf:int), ...]) tuple.
        """
        with closing(MultiFileReader()) as reader:
            for w, locs in self.posting_locs.items():
                #print(f"PostingLocsIter: w:{w}, \nlocs:{locs}") 
                b = reader.read(locs, self.df[w] * TUPLE_SIZE)
                posting_list = []
                for i in range(self.df[w]):
                    doc_id = int.from_bytes(b[i * TUPLE_SIZE:i * TUPLE_SIZE + 4], 'big')
                    tf = int.from_bytes(b[i * TUPLE_SIZE + 4:(i + 1) * TUPLE_SIZE], 'big')
                    posting_list.append((doc_id, tf))
                yield w, posting_list

    @staticmethod
    def read_index(base_dir, name):
        with open(Path(base_dir) / f'{name}.pkl', 'rb') as f:
            return pickle.load(f)

    @staticmethod
    def delete_index(base_dir, name):
        path_globals = Path(base_dir) / f'{name}.pkl'
        path_globals.unlink()
        for p in Path(base_dir).rglob(f'{name}_*.bin'):
            p.unlink()

    @staticmethod
    def write_a_posting_list(b_w_pl):
        ''' Takes a (bucket_id, [(w0, posting_list_0), (w1, posting_list_1), ...])
        and writes it out to disk as files named {bucket_id}_XXX.bin under the
        current directory. Returns a posting locations dictionary that maps each
        word to the list of files and offsets that contain its posting list.
        Parameters:
        -----------
          b_w_pl: tuple
            Containing a bucket id and all (word, posting list) pairs in that bucket
            (bucket_id, [(w0, posting_list_0), (w1, posting_list_1), ...])
        Return:
          posting_locs: dict
            Posting locations for each of the words written out in this bucket.
        '''
        posting_locs = defaultdict(list)
        bucket, list_w_pl = b_w_pl

        with closing(MultiFileWriter('.', bucket)) as writer:
            for w, pl in list_w_pl:
                # convert to bytes
                b = b''.join([(doc_id << 16 | (tf & TF_MASK)).to_bytes(TUPLE_SIZE, 'big')
                              for doc_id, tf in pl])
                # write to file(s)
                locs = writer.write(b)
                # save file locations to index
                posting_locs[w].extend(locs)
        return posting_locs
